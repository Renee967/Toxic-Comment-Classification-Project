# %% [markdown]
# # Toxic Comment Classification
#
# #### Dissertation Project
# ### Name: Renee Mendonca
# ### Student Number-221040908

# %% [markdown]
# # Models Used on Toxicity Type
# I have used 5 models-
# 1. CNN
# 2. Bidirectional LSTM
# 3. Bidirectional GRU
# 4. Bidirectional CNN
# 5. Ensemble Model
#
# As our dataset is multi-label so I have used OneVsRestClassifier()- as our toxic labels data has 1'0 and 0's as the values. OneVsRestClassifier performs better for this type of datasets as it accepts binary data over multiple labels and results of prediction is also in the form of 0's and 1's.

# %% [markdown]
# Mount Your Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# CNN Model

# %%
from keras.layers import Dense, Input, Conv2D, Embedding, Dropout, Reshape, Flatten, Lambda, concatenate
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.layers import GlobalMaxPool2D
from keras.optimizers import Adam
from keras.models import Model
import keras.backend as K
import tensorflow as tf
import numpy as np
import random
import time

# Fix seeds for reproducibility
np.random.seed(7)
tf.random.set_seed(7)  # Use tf.random.set_seed in newer TensorFlow versions
random.seed(7)

def get_f1(y_true, y_pred):
    y_pred = tf.cast(y_pred >= 0.5, tf.float32)
    TP = tf.reduce_sum(tf.cast(y_true * y_pred, tf.float32), axis=0)
    FP = tf.reduce_sum(tf.cast((1 - y_true) * y_pred, tf.float32), axis=0)
    FN = tf.reduce_sum(tf.cast(y_true * (1 - y_pred), tf.float32), axis=0)

    precision = TP / (TP + FP + K.epsilon())
    recall = TP / (TP + FN + K.epsilon())

    f1 = 2 * (precision * recall) / (precision + recall + K.epsilon())
    return tf.reduce_mean(f1)

def f1_score_metric(y_true, y_pred):
    return get_f1(y_true, y_pred)

start_time = time.time()

TRAIN_DATA_FILE = "/content/drive/My Drive/toxic-comments-classification/toxicity-types-data/training-data-tokenized.csv"
VALIDATION_DATA_FILE = "/content/drive/My Drive/toxic-comments-classification/toxicity-types-data/validation-data-tokenized.csv"
EMBEDDING_FILE = "/content/drive/My Drive/toxic-comments-classification/toxicity-types-data/fasttext-embedding-matrix.csv"

# Parameters
max_comment_length = 150
vector_size = 300

# Read data
training_data = np.loadtxt(TRAIN_DATA_FILE, delimiter=',')
print(training_data.shape)

training_input = training_data[:, :max_comment_length]
print(training_input.shape)

training_labels = training_data[:, max_comment_length:max_comment_length + 6]
print(training_labels.shape)

embedding_matrix = np.loadtxt(EMBEDDING_FILE, delimiter=',')
print(embedding_matrix.shape)
vocab_count = embedding_matrix.shape[0]
print(vocab_count)

validation_data = np.loadtxt(VALIDATION_DATA_FILE, delimiter=',')
validation_input = validation_data[:, :max_comment_length]
validation_labels = validation_data[:, max_comment_length:max_comment_length + 6]
print(validation_labels.shape)

total_records_count = validation_data.shape[0]
class_records_count = np.sum(validation_labels, axis=0)
print(class_records_count)
print(total_records_count)

class_percentage = class_records_count / total_records_count
print(class_percentage)

target = np.sum(class_percentage)
print(target)

# Build model
input_layer = Input(shape=(max_comment_length, ))

x = Embedding(input_dim=vocab_count, output_dim=vector_size, weights=[embedding_matrix], trainable=True)(input_layer)
x_reshaped = Reshape((max_comment_length, vector_size, 1))(x)
cnn_output = Conv2D(filters=300, kernel_size=(4, vector_size), activation='relu', data_format="channels_last")(x_reshaped)
pooling_output = GlobalMaxPool2D()(cnn_output)
dense1_output = Dense(50, activation="relu")(pooling_output)
dropout1_output = Dropout(0.2)(dense1_output)
output_layer = Dense(6, activation="sigmoid")(dropout1_output)

# Compile model
model = Model(inputs=input_layer, outputs=output_layer)
print(model.summary())

model.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate=0.0002), metrics=['accuracy', f1_score_metric])

# Callbacks for early stopping and saving the best model
checkpoint = ModelCheckpoint('model-cnn.h5', monitor='val_f1_score_metric', verbose=1, save_best_only=True, mode='max')
early_stopping = EarlyStopping(monitor='val_f1_score_metric', patience=5, mode='max')

callbacks_list = [checkpoint, early_stopping]

model.fit(training_input, training_labels, batch_size=1024, epochs=100, callbacks=callbacks_list,
          validation_data=(validation_input, validation_labels))

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (36491, 156)
# (36491, 150)
# (36491, 6)
# (29355, 300)
# 29355
# (1622, 6)
# [1531.  148.  850.   54.  833.  142.]
# 1622
# [0.94389642 0.09124538 0.52404439 0.03329223 0.5135635  0.08754624]
# 2.193588162762022
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 150)]             0
#
#  embedding_1 (Embedding)     (None, 150, 300)          8806500
#
#  reshape_1 (Reshape)         (None, 150, 300, 1)       0
#
#  conv2d_1 (Conv2D)           (None, 147, 1, 300)       360300
#
#  global_max_pooling2d_1 (Gl  (None, 300)               0
#  obalMaxPooling2D)
#
#  dense_2 (Dense)             (None, 50)                15050
#
#  dropout_1 (Dropout)         (None, 50)                0
#
#  dense_3 (Dense)             (None, 6)                 306
#
# =================================================================
# Total params: 9182156 (35.03 MB)
# Trainable params: 9182156 (35.03 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/100
# 36/36 [==============================] - ETA: 0s - loss: 0.5348 - accuracy: 0.6649 - f1_score_metric: 0.5798
# Epoch 1: val_f1_score_metric improved from -inf to 0.44186, saving model to model-cnn.h5
# 36/36 [==============================] - 10s 231ms/step - loss: 0.5348 - accuracy: 0.6649 - f1_score_metric: 0.5798 - val_loss: 0.4085 - val_accuracy: 0.9420 - val_f1_score_metric: 0.4419
# Epoch 2/100
# 36/36 [==============================] - ETA: 0s - loss: 0.3999 - accuracy: 0.8666 - f1_score_metric: 0.6450
# Epoch 2: val_f1_score_metric improved from 0.44186 to 0.55925, saving model to model-cnn.h5
# 36/36 [==============================] - 8s 217ms/step - loss: 0.3999 - accuracy: 0.8666 - f1_score_metric: 0.6450 - val_loss: 0.3496 - val_accuracy: 0.9427 - val_f1_score_metric: 0.5592
# Epoch 3/100
# 36/36 [==============================] - ETA: 0s - loss: 0.3386 - accuracy: 0.8089 - f1_score_metric: 0.7079
# Epoch 3: val_f1_score_metric improved from 0.55925 to 0.58900, saving model to model-cnn.h5
# 36/36 [==============================] - 8s 222ms/step - loss: 0.3386 - accuracy: 0.8089 - f1_score_metric: 0.7079 - val_loss: 0.3260 - val_accuracy: 0.9383 - val_f1_score_metric: 0.5890
# Epoch 4/100
# 36/36 [==============================] - ETA: 0s - loss: 0.2979 - accuracy: 0.7645 - f1_score_metric: 0.7537
# Epoch 4: val_f1_score_metric improved from 0.58900 to 0.59510, saving model to model-cnn.h5
# 36/36 [==============================] - 8s 226ms/step - loss: 0.2979 - accuracy: 0.7645 - f1_score_metric: 0.7537 - val_loss: 0.3166 - val_accuracy: 0.9211 - val_f1_score_metric: 0.5951
# Epoch 5/100
# 36/36 [==============================] - ETA: 0s - loss: 0.2694 - accuracy: 0.7479 - f1_score_metric: 0.7976
# Epoch 5: val_f1_score_metric improved from 0.59510 to 0.62700, saving model to model-cnn.h5
# 36/36 [==============================] - 8s 215ms/step - loss: 0.2694 - accuracy: 0.7479 - f1_score_metric: 0.7976 - val_loss: 0.3031 - val_accuracy: 0.9149 - val_f1_score_metric: 0.6270
# Epoch 6/100
# 36/36 [==============================] - ETA: 0s - loss: 0.2457 - accuracy: 0.7410 - f1_score_metric: 0.8279
# Epoch 6: val_f1_score_metric improved from 0.62700 to 0.65787, saving model to model-cnn.h5
# 36/36 [==============================] - 8s 225ms/step - loss: 0.2457 - accuracy: 0.7410 - f1_score_metric: 0.8279 - val_loss: 0.2960 - val_accuracy: 0.9131 - val_f1_score_metric: 0.6579
# Epoch 7/100
# 36/36 [==============================] - ETA: 0s - loss: 0.2257 - accuracy: 0.7338 - f1_score_metric: 0.8486
# Epoch 7: val_f1_score_metric improved from 0.65787 to 0.66993, saving model to model-cnn.h5
# 36/36 [==============================] - 10s 274ms/step - loss: 0.2257 - accuracy: 0.7338 - f1_score_metric: 0.8486 - val_loss: 0.2944 - val_accuracy: 0.9100 - val_f1_score_metric: 0.6699
# Epoch 8/100
# 36/36 [==============================] - ETA: 0s - loss: 0.2097 - accuracy: 0.7290 - f1_score_metric: 0.8677
# Epoch 8: val_f1_score_metric improved from 0.66993 to 0.67933, saving model to model-cnn.h5
# 36/36 [==============================] - 9s 246ms/step - loss: 0.2097 - accuracy: 0.7290 - f1_score_metric: 0.8677 - val_loss: 0.2907 - val_accuracy: 0.9051 - val_f1_score_metric: 0.6793
# Epoch 9/100
# 36/36 [==============================] - ETA: 0s - loss: 0.1945 - accuracy: 0.7221 - f1_score_metric: 0.8804
# Epoch 9: val_f1_score_metric did not improve from 0.67933
# 36/36 [==============================] - 9s 256ms/step - loss: 0.1945 - accuracy: 0.7221 - f1_score_metric: 0.8804 - val_loss: 0.2944 - val_accuracy: 0.8946 - val_f1_score_metric: 0.6791
# Epoch 10/100
# 36/36 [==============================] - ETA: 0s - loss: 0.1809 - accuracy: 0.7064 - f1_score_metric: 0.8947
# Epoch 10: val_f1_score_metric did not improve from 0.67933
# 36/36 [==============================] - 9s 245ms/step - loss: 0.1809 - accuracy: 0.7064 - f1_score_metric: 0.8947 - val_loss: 0.2884 - val_accuracy: 0.8983 - val_f1_score_metric: 0.6753
# Epoch 11/100
# 36/36 [==============================] - ETA: 0s - loss: 0.1675 - accuracy: 0.7045 - f1_score_metric: 0.9040
# Epoch 11: val_f1_score_metric improved from 0.67933 to 0.68378, saving model to model-cnn.h5
# 36/36 [==============================] - 9s 239ms/step - loss: 0.1675 - accuracy: 0.7045 - f1_score_metric: 0.9040 - val_loss: 0.2899 - val_accuracy: 0.9020 - val_f1_score_metric: 0.6838
# Epoch 12/100
# 36/36 [==============================] - ETA: 0s - loss: 0.1562 - accuracy: 0.7056 - f1_score_metric: 0.9137
# Epoch 12: val_f1_score_metric did not improve from 0.68378
# 36/36 [==============================] - 9s 239ms/step - loss: 0.1562 - accuracy: 0.7056 - f1_score_metric: 0.9137 - val_loss: 0.2937 - val_accuracy: 0.8909 - val_f1_score_metric: 0.6832
# Epoch 13/100
# 36/36 [==============================] - ETA: 0s - loss: 0.1455 - accuracy: 0.6932 - f1_score_metric: 0.9208
# Epoch 13: val_f1_score_metric improved from 0.68378 to 0.68430, saving model to model-cnn.h5
# 36/36 [==============================] - 8s 220ms/step - loss: 0.1455 - accuracy: 0.6932 - f1_score_metric: 0.9208 - val_loss: 0.2965 - val_accuracy: 0.8884 - val_f1_score_metric: 0.6843
# Epoch 14/100
# 36/36 [==============================] - ETA: 0s - loss: 0.1356 - accuracy: 0.6927 - f1_score_metric: 0.9275
# Epoch 14: val_f1_score_metric did not improve from 0.68430
# 36/36 [==============================] - 8s 211ms/step - loss: 0.1356 - accuracy: 0.6927 - f1_score_metric: 0.9275 - val_loss: 0.3013 - val_accuracy: 0.8798 - val_f1_score_metric: 0.6750
# Epoch 15/100
# 36/36 [==============================] - ETA: 0s - loss: 0.1273 - accuracy: 0.6866 - f1_score_metric: 0.9331
# Epoch 15: val_f1_score_metric did not improve from 0.68430
# 36/36 [==============================] - 8s 229ms/step - loss: 0.1273 - accuracy: 0.6866 - f1_score_metric: 0.9331 - val_loss: 0.3029 - val_accuracy: 0.8681 - val_f1_score_metric: 0.6763
# Epoch 16/100
# 36/36 [==============================] - ETA: 0s - loss: 0.1192 - accuracy: 0.6745 - f1_score_metric: 0.9391
# Epoch 16: val_f1_score_metric did not improve from 0.68430
# 36/36 [==============================] - 7s 206ms/step - loss: 0.1192 - accuracy: 0.6745 - f1_score_metric: 0.9391 - val_loss: 0.3114 - val_accuracy: 0.8637 - val_f1_score_metric: 0.6715
# Epoch 17/100
# 36/36 [==============================] - ETA: 0s - loss: 0.1118 - accuracy: 0.6736 - f1_score_metric: 0.9425
# Epoch 17: val_f1_score_metric did not improve from 0.68430
# 36/36 [==============================] - 7s 206ms/step - loss: 0.1118 - accuracy: 0.6736 - f1_score_metric: 0.9425 - val_loss: 0.3159 - val_accuracy: 0.8564 - val_f1_score_metric: 0.6702
# Epoch 18/100
# 36/36 [==============================] - ETA: 0s - loss: 0.1059 - accuracy: 0.6667 - f1_score_metric: 0.9466
# Epoch 18: val_f1_score_metric did not improve from 0.68430
# 36/36 [==============================] - 7s 202ms/step - loss: 0.1059 - accuracy: 0.6667 - f1_score_metric: 0.9466 - val_loss: 0.3217 - val_accuracy: 0.8477 - val_f1_score_metric: 0.6682
# --- 162.10142636299133 seconds ---

# %% [markdown]
# Bidirectional LSTM Model

# %%
# !pip install --upgrade tensorflow
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.31.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (71.0.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.64.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.17.0)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.25.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.43.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (13.7.1)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.7.4)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)

# %%
from keras.layers import Dense, Input, LSTM, Bidirectional, Embedding, Dropout
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.layers import GlobalMaxPool1D
from keras.optimizers import Adam
from sklearn.metrics import roc_auc_score
from keras.models import Model
import tensorflow as tf
from tensorflow.keras.metrics import AUC # Import AUC here
import numpy as np
import random
import time

# fix seeds for re-producability
np.random.seed(7)
tf.random.set_seed(7)  # Use tf.random.set_seed in newer TensorFlow versions
random.seed(7)

# Initialize AUC metric outside the tf.function
auc_metric = AUC()

# Remove .numpy() call within the metric function
def get_roc_auc(actual, predicted):
    # Assuming 'actual' and 'predicted' are TensorFlow tensors
    auc_metric.update_state(actual, predicted)
    # Return the symbolic tensor representing AUC
    return auc_metric.result()

def get_f1(actual, predicted):
  TP = tf.math.count_nonzero(predicted * actual)
  TN = tf.math.count_nonzero((predicted - 1) * (actual - 1))
  FP = tf.math.count_nonzero(predicted * (actual - 1))
  FN = tf.math.count_nonzero((predicted - 1) * actual)

  precision = tf.divide(TP, TP + FP)
  recall = tf.divide(TP, TP + FN)

  f1 = tf.divide(2 * precision * recall, precision + recall)
  return f1

def f1_score_metric(actual, predicted):
  predicted = tf.cast(predicted>=0.5, tf.int32) # Use tf.cast for type conversion
  actual = tf.cast(actual, tf.int32) # Use tf.cast for type conversion

  # Calculate class_percentage and target here
  total_records_count = tf.cast(tf.shape(actual)[0], tf.float32)
  class_records_count = tf.reduce_sum(tf.cast(actual, tf.float32), axis=0)
  class_percentage = tf.cast(class_records_count / total_records_count, tf.float32) # Cast to float32
  target = tf.reduce_sum(class_percentage)

  new_overall_f1_weighted = 0.0 # Initialize as float32

  for class_id in range(0, 6):

    # F1 score
    f1 = get_f1(actual=actual[:, class_id], predicted=predicted[:, class_id])
    # Cast f1 to float32 to match class_percentage
    f1 = tf.cast(f1, tf.float32)

    new_overall_f1_weighted += f1 * class_percentage[class_id]


  return new_overall_f1_weighted/target

start_time = time.time()

TRAIN_DATA_FILE = "/content/drive/My Drive/toxic-comments-classification/toxicity-types-data/training-data-tokenized.csv"
VALIDATION_DATA_FILE = "/content/drive/My Drive/toxic-comments-classification/toxicity-types-data/validation-data-tokenized.csv"
EMBEDDING_FILE = "/content/drive/My Drive/toxic-comments-classification/toxicity-types-data/fasttext-embedding-matrix.csv"

# Parameters
max_comment_length = 150
vector_size = 300

# Read data
training_data = np.loadtxt(TRAIN_DATA_FILE, delimiter=',')
print(training_data.shape)

training_input = training_data[:, 0:max_comment_length]
print(training_input.shape)

training_labels = training_data[:, max_comment_length:156]
print(training_labels.shape)

embedding_matrix = np.loadtxt(EMBEDDING_FILE, delimiter=',')
print(embedding_matrix.shape)
vocab_count = embedding_matrix.shape[0]
print(vocab_count)

validation_data = np.loadtxt(VALIDATION_DATA_FILE, delimiter=',')

# Build model
input = Input(shape=(max_comment_length, ))

x = Embedding(input_dim=vocab_count, output_dim=vector_size, weights=[embedding_matrix], trainable=True)(input)

lstm_output = Bidirectional(LSTM(units=30, activation="tanh", return_sequences=True))(x)

pooling_output = GlobalMaxPool1D()(lstm_output)

dense1_output = Dense(60, activation="relu")(pooling_output)
dropout1_output = Dropout(0.2)(dense1_output)

dense2_output = Dense(60, activation="relu")(dropout1_output)
dropout2_output = Dropout(0.2)(dense2_output)

output = Dense(6, activation="sigmoid")(dropout2_output)


# Compile Model
model = Model(inputs=input, outputs=output)
print(model.summary())

model.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate=0.003), metrics=['accuracy', f1_score_metric, get_roc_auc])

# Callbacks for early stopping and saving the best model
# checkpoint = ModelCheckpoint('model-lstm.h5', monitor='val_f1_score_metric',
#                              verbose=1, save_best_only=True, mode='max')
# Callbacks for early stopping and saving the best model
checkpoint = ModelCheckpoint('model-lstm.keras', monitor='val_get_roc_auc', # Changed file extension to .keras
                             verbose=1, save_best_only=True, mode='max')

early_stopping = EarlyStopping(monitor='val_get_roc_auc', patience=5, mode='max')

callbacks_list = [checkpoint, early_stopping]

model.fit(training_input, training_labels, batch_size=1024, epochs=100, callbacks=callbacks_list,
          validation_data=(validation_data[:, 0:max_comment_length], validation_data[:,max_comment_length:156]))
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (36491, 156)
# (36491, 150)
# (36491, 6)
# (29355, 300)
# 29355
# Model: "functional_15"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_15 (InputLayer)          │ (None, 150)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ embedding_15 (Embedding)             │ (None, 150, 300)            │       8,806,500 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional_15 (Bidirectional)     │ (None, 150, 60)             │          79,440 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_max_pooling1d_15              │ (None, 60)                  │               0 │
# │ (GlobalMaxPooling1D)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_45 (Dense)                     │ (None, 60)                  │           3,660 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_30 (Dropout)                 │ (None, 60)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_46 (Dense)                     │ (None, 60)                  │           3,660 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_31 (Dropout)                 │ (None, 60)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_47 (Dense)                     │ (None, 6)                   │             366 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 8,893,626 (33.93 MB)
#  Trainable params: 8,893,626 (33.93 MB)
#  Non-trainable params: 0 (0.00 B)
# None
# Epoch 1/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.8214 - f1_score_metric: nan - get_roc_auc: 0.7752 - loss: 0.4932
# Epoch 1: val_get_roc_auc improved from -inf to 0.89683, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 14s 130ms/step - accuracy: 0.8211 - f1_score_metric: nan - get_roc_auc: 0.7768 - loss: 0.4909 - val_accuracy: 0.8681 - val_f1_score_metric: nan - val_get_roc_auc: 0.8968 - val_loss: 0.3267
# Epoch 2/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.6922 - f1_score_metric: 0.8888 - get_roc_auc: 0.9102 - loss: 0.2613
# Epoch 2: val_get_roc_auc improved from 0.89683 to 0.93641, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 14s 114ms/step - accuracy: 0.6925 - f1_score_metric: 0.8892 - get_roc_auc: 0.9105 - loss: 0.2606 - val_accuracy: 0.8576 - val_f1_score_metric: 0.8262 - val_get_roc_auc: 0.9364 - val_loss: 0.3024
# Epoch 3/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.7162 - f1_score_metric: 0.9350 - get_roc_auc: 0.9426 - loss: 0.1732
# Epoch 3: val_get_roc_auc improved from 0.93641 to 0.95542, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 5s 114ms/step - accuracy: 0.7164 - f1_score_metric: 0.9351 - get_roc_auc: 0.9427 - loss: 0.1729 - val_accuracy: 0.7774 - val_f1_score_metric: 0.8281 - val_get_roc_auc: 0.9554 - val_loss: 0.3344
# Epoch 4/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.7322 - f1_score_metric: 0.9543 - get_roc_auc: 0.9589 - loss: 0.1265
# Epoch 4: val_get_roc_auc improved from 0.95542 to 0.96631, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - accuracy: 0.7326 - f1_score_metric: 0.9544 - get_roc_auc: 0.9590 - loss: 0.1264 - val_accuracy: 0.8113 - val_f1_score_metric: 0.8208 - val_get_roc_auc: 0.9663 - val_loss: 0.3674
# Epoch 5/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.7602 - f1_score_metric: 0.9651 - get_roc_auc: 0.9685 - loss: 0.0972
# Epoch 5: val_get_roc_auc improved from 0.96631 to 0.97320, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step - accuracy: 0.7603 - f1_score_metric: 0.9651 - get_roc_auc: 0.9686 - loss: 0.0972 - val_accuracy: 0.7688 - val_f1_score_metric: 0.8208 - val_get_roc_auc: 0.9732 - val_loss: 0.4119
# Epoch 6/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.7922 - f1_score_metric: 0.9726 - get_roc_auc: 0.9747 - loss: 0.0791
# Epoch 6: val_get_roc_auc improved from 0.97320 to 0.97790, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 5s 111ms/step - accuracy: 0.7923 - f1_score_metric: 0.9726 - get_roc_auc: 0.9747 - loss: 0.0791 - val_accuracy: 0.7750 - val_f1_score_metric: 0.8189 - val_get_roc_auc: 0.9779 - val_loss: 0.4564
# Epoch 7/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.8015 - f1_score_metric: 0.9770 - get_roc_auc: 0.9790 - loss: 0.0646
# Epoch 7: val_get_roc_auc improved from 0.97790 to 0.98123, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 5s 110ms/step - accuracy: 0.8015 - f1_score_metric: 0.9770 - get_roc_auc: 0.9790 - loss: 0.0646 - val_accuracy: 0.7472 - val_f1_score_metric: 0.8130 - val_get_roc_auc: 0.9812 - val_loss: 0.5224
# Epoch 8/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.8063 - f1_score_metric: 0.9796 - get_roc_auc: 0.9820 - loss: 0.0580
# Epoch 8: val_get_roc_auc improved from 0.98123 to 0.98364, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 5s 115ms/step - accuracy: 0.8063 - f1_score_metric: 0.9796 - get_roc_auc: 0.9820 - loss: 0.0580 - val_accuracy: 0.8101 - val_f1_score_metric: 0.8005 - val_get_roc_auc: 0.9836 - val_loss: 0.6040
# Epoch 9/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.8145 - f1_score_metric: 0.9800 - get_roc_auc: 0.9842 - loss: 0.0557
# Epoch 9: val_get_roc_auc improved from 0.98364 to 0.98543, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 112ms/step - accuracy: 0.8148 - f1_score_metric: 0.9800 - get_roc_auc: 0.9842 - loss: 0.0556 - val_accuracy: 0.7343 - val_f1_score_metric: 0.8045 - val_get_roc_auc: 0.9854 - val_loss: 0.6019
# Epoch 10/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.8209 - f1_score_metric: 0.9822 - get_roc_auc: 0.9859 - loss: 0.0482
# Epoch 10: val_get_roc_auc improved from 0.98543 to 0.98684, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 5s 127ms/step - accuracy: 0.8211 - f1_score_metric: 0.9822 - get_roc_auc: 0.9859 - loss: 0.0482 - val_accuracy: 0.8403 - val_f1_score_metric: 0.8033 - val_get_roc_auc: 0.9868 - val_loss: 0.6719
# Epoch 11/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.8272 - f1_score_metric: 0.9846 - get_roc_auc: 0.9872 - loss: 0.0423
# Epoch 11: val_get_roc_auc improved from 0.98684 to 0.98797, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 5s 116ms/step - accuracy: 0.8273 - f1_score_metric: 0.9846 - get_roc_auc: 0.9872 - loss: 0.0423 - val_accuracy: 0.7855 - val_f1_score_metric: 0.8065 - val_get_roc_auc: 0.9880 - val_loss: 0.7133
# Epoch 12/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.8324 - f1_score_metric: 0.9843 - get_roc_auc: 0.9883 - loss: 0.0417
# Epoch 12: val_get_roc_auc improved from 0.98797 to 0.98886, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 5s 111ms/step - accuracy: 0.8324 - f1_score_metric: 0.9843 - get_roc_auc: 0.9883 - loss: 0.0417 - val_accuracy: 0.8150 - val_f1_score_metric: 0.8111 - val_get_roc_auc: 0.9889 - val_loss: 0.7302
# Epoch 13/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.8394 - f1_score_metric: 0.9856 - get_roc_auc: 0.9891 - loss: 0.0385
# Epoch 13: val_get_roc_auc improved from 0.98886 to 0.98961, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 121ms/step - accuracy: 0.8393 - f1_score_metric: 0.9856 - get_roc_auc: 0.9891 - loss: 0.0385 - val_accuracy: 0.8465 - val_f1_score_metric: 0.8078 - val_get_roc_auc: 0.9896 - val_loss: 0.7854
# Epoch 14/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.8457 - f1_score_metric: 0.9860 - get_roc_auc: 0.9898 - loss: 0.0371
# Epoch 14: val_get_roc_auc improved from 0.98961 to 0.99022, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 5s 116ms/step - accuracy: 0.8456 - f1_score_metric: 0.9860 - get_roc_auc: 0.9898 - loss: 0.0371 - val_accuracy: 0.8058 - val_f1_score_metric: 0.8020 - val_get_roc_auc: 0.9902 - val_loss: 0.7866
# Epoch 15/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.8364 - f1_score_metric: 0.9865 - get_roc_auc: 0.9904 - loss: 0.0349
# Epoch 15: val_get_roc_auc improved from 0.99022 to 0.99074, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - accuracy: 0.8365 - f1_score_metric: 0.9866 - get_roc_auc: 0.9904 - loss: 0.0349 - val_accuracy: 0.8311 - val_f1_score_metric: 0.8065 - val_get_roc_auc: 0.9907 - val_loss: 0.8296
# Epoch 16/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.8429 - f1_score_metric: 0.9873 - get_roc_auc: 0.9909 - loss: 0.0332
# Epoch 16: val_get_roc_auc improved from 0.99074 to 0.99118, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - accuracy: 0.8429 - f1_score_metric: 0.9873 - get_roc_auc: 0.9909 - loss: 0.0332 - val_accuracy: 0.8095 - val_f1_score_metric: 0.8031 - val_get_roc_auc: 0.9912 - val_loss: 0.8361
# Epoch 17/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.8437 - f1_score_metric: 0.9875 - get_roc_auc: 0.9913 - loss: 0.0320
# Epoch 17: val_get_roc_auc improved from 0.99118 to 0.99157, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - accuracy: 0.8439 - f1_score_metric: 0.9875 - get_roc_auc: 0.9913 - loss: 0.0320 - val_accuracy: 0.8323 - val_f1_score_metric: 0.8051 - val_get_roc_auc: 0.9916 - val_loss: 0.8710
# Epoch 18/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.8479 - f1_score_metric: 0.9877 - get_roc_auc: 0.9917 - loss: 0.0310
# Epoch 18: val_get_roc_auc improved from 0.99157 to 0.99189, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 112ms/step - accuracy: 0.8478 - f1_score_metric: 0.9877 - get_roc_auc: 0.9917 - loss: 0.0310 - val_accuracy: 0.8169 - val_f1_score_metric: 0.8067 - val_get_roc_auc: 0.9919 - val_loss: 0.9153
# Epoch 19/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.8474 - f1_score_metric: 0.9877 - get_roc_auc: 0.9920 - loss: 0.0309
# Epoch 19: val_get_roc_auc improved from 0.99189 to 0.99217, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 113ms/step - accuracy: 0.8475 - f1_score_metric: 0.9877 - get_roc_auc: 0.9920 - loss: 0.0309 - val_accuracy: 0.8403 - val_f1_score_metric: 0.8010 - val_get_roc_auc: 0.9922 - val_loss: 0.9292
# Epoch 20/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.8553 - f1_score_metric: 0.9880 - get_roc_auc: 0.9923 - loss: 0.0302
# Epoch 20: val_get_roc_auc improved from 0.99217 to 0.99241, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 123ms/step - accuracy: 0.8552 - f1_score_metric: 0.9880 - get_roc_auc: 0.9923 - loss: 0.0302 - val_accuracy: 0.7855 - val_f1_score_metric: 0.7945 - val_get_roc_auc: 0.9924 - val_loss: 0.9423
# Epoch 21/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.8347 - f1_score_metric: 0.9879 - get_roc_auc: 0.9925 - loss: 0.0310
# Epoch 21: val_get_roc_auc improved from 0.99241 to 0.99262, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 5s 113ms/step - accuracy: 0.8349 - f1_score_metric: 0.9879 - get_roc_auc: 0.9925 - loss: 0.0310 - val_accuracy: 0.7830 - val_f1_score_metric: 0.8022 - val_get_roc_auc: 0.9926 - val_loss: 0.9511
# Epoch 22/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.8465 - f1_score_metric: 0.9882 - get_roc_auc: 0.9927 - loss: 0.0291
# Epoch 22: val_get_roc_auc improved from 0.99262 to 0.99280, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 5s 112ms/step - accuracy: 0.8466 - f1_score_metric: 0.9882 - get_roc_auc: 0.9927 - loss: 0.0291 - val_accuracy: 0.7707 - val_f1_score_metric: 0.7944 - val_get_roc_auc: 0.9928 - val_loss: 0.9778
# Epoch 23/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.8456 - f1_score_metric: 0.9883 - get_roc_auc: 0.9929 - loss: 0.0288
# Epoch 23: val_get_roc_auc improved from 0.99280 to 0.99297, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 5s 115ms/step - accuracy: 0.8457 - f1_score_metric: 0.9883 - get_roc_auc: 0.9929 - loss: 0.0288 - val_accuracy: 0.8046 - val_f1_score_metric: 0.8022 - val_get_roc_auc: 0.9930 - val_loss: 0.9845
# Epoch 24/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.8567 - f1_score_metric: 0.9887 - get_roc_auc: 0.9930 - loss: 0.0290
# Epoch 24: val_get_roc_auc improved from 0.99297 to 0.99311, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - accuracy: 0.8567 - f1_score_metric: 0.9887 - get_roc_auc: 0.9930 - loss: 0.0290 - val_accuracy: 0.8157 - val_f1_score_metric: 0.8012 - val_get_roc_auc: 0.9931 - val_loss: 1.0109
# Epoch 25/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.8519 - f1_score_metric: 0.9887 - get_roc_auc: 0.9932 - loss: 0.0282
# Epoch 25: val_get_roc_auc improved from 0.99311 to 0.99325, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 119ms/step - accuracy: 0.8518 - f1_score_metric: 0.9887 - get_roc_auc: 0.9932 - loss: 0.0282 - val_accuracy: 0.7996 - val_f1_score_metric: 0.7976 - val_get_roc_auc: 0.9932 - val_loss: 1.0355
# Epoch 26/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.8567 - f1_score_metric: 0.9885 - get_roc_auc: 0.9933 - loss: 0.0285
# Epoch 26: val_get_roc_auc improved from 0.99325 to 0.99336, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - accuracy: 0.8568 - f1_score_metric: 0.9885 - get_roc_auc: 0.9933 - loss: 0.0285 - val_accuracy: 0.8076 - val_f1_score_metric: 0.7942 - val_get_roc_auc: 0.9934 - val_loss: 1.0233
# Epoch 27/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.8519 - f1_score_metric: 0.9886 - get_roc_auc: 0.9934 - loss: 0.0282
# Epoch 27: val_get_roc_auc improved from 0.99336 to 0.99347, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 112ms/step - accuracy: 0.8521 - f1_score_metric: 0.9886 - get_roc_auc: 0.9934 - loss: 0.0282 - val_accuracy: 0.8440 - val_f1_score_metric: 0.8019 - val_get_roc_auc: 0.9935 - val_loss: 1.0527
# Epoch 28/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.8713 - f1_score_metric: 0.9884 - get_roc_auc: 0.9935 - loss: 0.0275
# Epoch 28: val_get_roc_auc improved from 0.99347 to 0.99356, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 122ms/step - accuracy: 0.8711 - f1_score_metric: 0.9884 - get_roc_auc: 0.9935 - loss: 0.0275 - val_accuracy: 0.7818 - val_f1_score_metric: 0.7989 - val_get_roc_auc: 0.9936 - val_loss: 1.0771
# Epoch 29/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.8653 - f1_score_metric: 0.9887 - get_roc_auc: 0.9936 - loss: 0.0271
# Epoch 29: val_get_roc_auc improved from 0.99356 to 0.99365, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 118ms/step - accuracy: 0.8654 - f1_score_metric: 0.9887 - get_roc_auc: 0.9936 - loss: 0.0271 - val_accuracy: 0.8274 - val_f1_score_metric: 0.8001 - val_get_roc_auc: 0.9937 - val_loss: 1.0791
# Epoch 30/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.8722 - f1_score_metric: 0.9891 - get_roc_auc: 0.9937 - loss: 0.0261
# Epoch 30: val_get_roc_auc improved from 0.99365 to 0.99373, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 5s 111ms/step - accuracy: 0.8722 - f1_score_metric: 0.9891 - get_roc_auc: 0.9937 - loss: 0.0261 - val_accuracy: 0.7614 - val_f1_score_metric: 0.7993 - val_get_roc_auc: 0.9937 - val_loss: 1.1011
# Epoch 31/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.8544 - f1_score_metric: 0.9892 - get_roc_auc: 0.9938 - loss: 0.0262
# Epoch 31: val_get_roc_auc improved from 0.99373 to 0.99380, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 112ms/step - accuracy: 0.8545 - f1_score_metric: 0.9892 - get_roc_auc: 0.9938 - loss: 0.0262 - val_accuracy: 0.8218 - val_f1_score_metric: 0.8011 - val_get_roc_auc: 0.9938 - val_loss: 1.1297
# Epoch 32/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.8705 - f1_score_metric: 0.9887 - get_roc_auc: 0.9938 - loss: 0.0265
# Epoch 32: val_get_roc_auc improved from 0.99380 to 0.99386, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 121ms/step - accuracy: 0.8705 - f1_score_metric: 0.9887 - get_roc_auc: 0.9938 - loss: 0.0265 - val_accuracy: 0.8027 - val_f1_score_metric: 0.8056 - val_get_roc_auc: 0.9939 - val_loss: 1.1318
# Epoch 33/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.8763 - f1_score_metric: 0.9892 - get_roc_auc: 0.9939 - loss: 0.0259
# Epoch 33: val_get_roc_auc improved from 0.99386 to 0.99393, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 5s 112ms/step - accuracy: 0.8764 - f1_score_metric: 0.9892 - get_roc_auc: 0.9939 - loss: 0.0259 - val_accuracy: 0.7910 - val_f1_score_metric: 0.7993 - val_get_roc_auc: 0.9939 - val_loss: 1.1146
# Epoch 34/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.8795 - f1_score_metric: 0.9892 - get_roc_auc: 0.9940 - loss: 0.0261
# Epoch 34: val_get_roc_auc improved from 0.99393 to 0.99398, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 5s 117ms/step - accuracy: 0.8796 - f1_score_metric: 0.9892 - get_roc_auc: 0.9940 - loss: 0.0261 - val_accuracy: 0.8243 - val_f1_score_metric: 0.8030 - val_get_roc_auc: 0.9940 - val_loss: 1.1632
# Epoch 35/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.8668 - f1_score_metric: 0.9889 - get_roc_auc: 0.9940 - loss: 0.0260
# Epoch 35: val_get_roc_auc improved from 0.99398 to 0.99403, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - accuracy: 0.8669 - f1_score_metric: 0.9889 - get_roc_auc: 0.9940 - loss: 0.0260 - val_accuracy: 0.7947 - val_f1_score_metric: 0.8060 - val_get_roc_auc: 0.9940 - val_loss: 1.1807
# Epoch 36/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.8812 - f1_score_metric: 0.9891 - get_roc_auc: 0.9941 - loss: 0.0252
# Epoch 36: val_get_roc_auc improved from 0.99403 to 0.99408, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 112ms/step - accuracy: 0.8813 - f1_score_metric: 0.9891 - get_roc_auc: 0.9941 - loss: 0.0252 - val_accuracy: 0.8292 - val_f1_score_metric: 0.8056 - val_get_roc_auc: 0.9941 - val_loss: 1.1987
# Epoch 37/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.8709 - f1_score_metric: 0.9894 - get_roc_auc: 0.9941 - loss: 0.0251
# Epoch 37: val_get_roc_auc improved from 0.99408 to 0.99412, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 5s 118ms/step - accuracy: 0.8709 - f1_score_metric: 0.9894 - get_roc_auc: 0.9941 - loss: 0.0251 - val_accuracy: 0.8434 - val_f1_score_metric: 0.8061 - val_get_roc_auc: 0.9941 - val_loss: 1.2215
# Epoch 38/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.8861 - f1_score_metric: 0.9895 - get_roc_auc: 0.9941 - loss: 0.0252
# Epoch 38: val_get_roc_auc improved from 0.99412 to 0.99416, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 5s 126ms/step - accuracy: 0.8859 - f1_score_metric: 0.9895 - get_roc_auc: 0.9941 - loss: 0.0252 - val_accuracy: 0.8342 - val_f1_score_metric: 0.8014 - val_get_roc_auc: 0.9942 - val_loss: 1.2150
# Epoch 39/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.8841 - f1_score_metric: 0.9893 - get_roc_auc: 0.9942 - loss: 0.0250
# Epoch 39: val_get_roc_auc improved from 0.99416 to 0.99420, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 113ms/step - accuracy: 0.8840 - f1_score_metric: 0.9893 - get_roc_auc: 0.9942 - loss: 0.0250 - val_accuracy: 0.8453 - val_f1_score_metric: 0.8069 - val_get_roc_auc: 0.9942 - val_loss: 1.2349
# Epoch 40/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.8893 - f1_score_metric: 0.9894 - get_roc_auc: 0.9942 - loss: 0.0250
# Epoch 40: val_get_roc_auc improved from 0.99420 to 0.99423, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 113ms/step - accuracy: 0.8890 - f1_score_metric: 0.9894 - get_roc_auc: 0.9942 - loss: 0.0250 - val_accuracy: 0.8496 - val_f1_score_metric: 0.7960 - val_get_roc_auc: 0.9942 - val_loss: 1.3004
# Epoch 41/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.8953 - f1_score_metric: 0.9895 - get_roc_auc: 0.9942 - loss: 0.0251
# Epoch 41: val_get_roc_auc improved from 0.99423 to 0.99426, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 123ms/step - accuracy: 0.8950 - f1_score_metric: 0.9895 - get_roc_auc: 0.9942 - loss: 0.0250 - val_accuracy: 0.8471 - val_f1_score_metric: 0.7976 - val_get_roc_auc: 0.9943 - val_loss: 1.2903
# Epoch 42/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.8969 - f1_score_metric: 0.9892 - get_roc_auc: 0.9943 - loss: 0.0247
# Epoch 42: val_get_roc_auc improved from 0.99426 to 0.99429, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - accuracy: 0.8967 - f1_score_metric: 0.9892 - get_roc_auc: 0.9943 - loss: 0.0247 - val_accuracy: 0.8711 - val_f1_score_metric: 0.8018 - val_get_roc_auc: 0.9943 - val_loss: 1.3138
# Epoch 43/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.8852 - f1_score_metric: 0.9892 - get_roc_auc: 0.9943 - loss: 0.0251
# Epoch 43: val_get_roc_auc improved from 0.99429 to 0.99432, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 5s 116ms/step - accuracy: 0.8848 - f1_score_metric: 0.9892 - get_roc_auc: 0.9943 - loss: 0.0251 - val_accuracy: 0.8298 - val_f1_score_metric: 0.8028 - val_get_roc_auc: 0.9943 - val_loss: 1.2908
# Epoch 44/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.9025 - f1_score_metric: 0.9894 - get_roc_auc: 0.9943 - loss: 0.0247
# Epoch 44: val_get_roc_auc improved from 0.99432 to 0.99434, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 5s 126ms/step - accuracy: 0.9024 - f1_score_metric: 0.9894 - get_roc_auc: 0.9943 - loss: 0.0247 - val_accuracy: 0.8157 - val_f1_score_metric: 0.7966 - val_get_roc_auc: 0.9943 - val_loss: 1.2848
# Epoch 45/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.8774 - f1_score_metric: 0.9894 - get_roc_auc: 0.9944 - loss: 0.0244
# Epoch 45: val_get_roc_auc improved from 0.99434 to 0.99437, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 113ms/step - accuracy: 0.8773 - f1_score_metric: 0.9894 - get_roc_auc: 0.9944 - loss: 0.0244 - val_accuracy: 0.8446 - val_f1_score_metric: 0.7986 - val_get_roc_auc: 0.9944 - val_loss: 1.3209
# Epoch 46/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.8881 - f1_score_metric: 0.9894 - get_roc_auc: 0.9944 - loss: 0.0251
# Epoch 46: val_get_roc_auc improved from 0.99437 to 0.99439, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 121ms/step - accuracy: 0.8879 - f1_score_metric: 0.9894 - get_roc_auc: 0.9944 - loss: 0.0251 - val_accuracy: 0.7663 - val_f1_score_metric: 0.7993 - val_get_roc_auc: 0.9944 - val_loss: 1.1704
# Epoch 47/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.8786 - f1_score_metric: 0.9893 - get_roc_auc: 0.9944 - loss: 0.0257
# Epoch 47: val_get_roc_auc improved from 0.99439 to 0.99441, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 5s 127ms/step - accuracy: 0.8786 - f1_score_metric: 0.9893 - get_roc_auc: 0.9944 - loss: 0.0257 - val_accuracy: 0.7947 - val_f1_score_metric: 0.7974 - val_get_roc_auc: 0.9944 - val_loss: 1.2259
# Epoch 48/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.8898 - f1_score_metric: 0.9895 - get_roc_auc: 0.9944 - loss: 0.0248
# Epoch 48: val_get_roc_auc improved from 0.99441 to 0.99443, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 5s 114ms/step - accuracy: 0.8898 - f1_score_metric: 0.9895 - get_roc_auc: 0.9944 - loss: 0.0248 - val_accuracy: 0.7830 - val_f1_score_metric: 0.7980 - val_get_roc_auc: 0.9944 - val_loss: 1.3036
# Epoch 49/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.8771 - f1_score_metric: 0.9897 - get_roc_auc: 0.9945 - loss: 0.0237
# Epoch 49: val_get_roc_auc improved from 0.99443 to 0.99445, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 112ms/step - accuracy: 0.8771 - f1_score_metric: 0.9897 - get_roc_auc: 0.9945 - loss: 0.0238 - val_accuracy: 0.8021 - val_f1_score_metric: 0.8032 - val_get_roc_auc: 0.9945 - val_loss: 1.3161
# Epoch 50/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.8878 - f1_score_metric: 0.9897 - get_roc_auc: 0.9945 - loss: 0.0239
# Epoch 50: val_get_roc_auc improved from 0.99445 to 0.99447, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 123ms/step - accuracy: 0.8878 - f1_score_metric: 0.9897 - get_roc_auc: 0.9945 - loss: 0.0239 - val_accuracy: 0.7725 - val_f1_score_metric: 0.8006 - val_get_roc_auc: 0.9945 - val_loss: 1.3626
# Epoch 51/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.8899 - f1_score_metric: 0.9898 - get_roc_auc: 0.9945 - loss: 0.0232
# Epoch 51: val_get_roc_auc improved from 0.99447 to 0.99448, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 5s 114ms/step - accuracy: 0.8898 - f1_score_metric: 0.9898 - get_roc_auc: 0.9945 - loss: 0.0232 - val_accuracy: 0.8157 - val_f1_score_metric: 0.8016 - val_get_roc_auc: 0.9945 - val_loss: 1.4214
# Epoch 52/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.9021 - f1_score_metric: 0.9901 - get_roc_auc: 0.9945 - loss: 0.0232
# Epoch 52: val_get_roc_auc improved from 0.99448 to 0.99450, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 5s 115ms/step - accuracy: 0.9021 - f1_score_metric: 0.9901 - get_roc_auc: 0.9945 - loss: 0.0232 - val_accuracy: 0.8138 - val_f1_score_metric: 0.8005 - val_get_roc_auc: 0.9945 - val_loss: 1.3991
# Epoch 53/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9033 - f1_score_metric: 0.9897 - get_roc_auc: 0.9945 - loss: 0.0231
# Epoch 53: val_get_roc_auc improved from 0.99450 to 0.99451, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - accuracy: 0.9032 - f1_score_metric: 0.9897 - get_roc_auc: 0.9945 - loss: 0.0231 - val_accuracy: 0.7990 - val_f1_score_metric: 0.8030 - val_get_roc_auc: 0.9945 - val_loss: 1.4234
# Epoch 54/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.8914 - f1_score_metric: 0.9900 - get_roc_auc: 0.9945 - loss: 0.0231
# Epoch 54: val_get_roc_auc improved from 0.99451 to 0.99452, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - accuracy: 0.8914 - f1_score_metric: 0.9900 - get_roc_auc: 0.9945 - loss: 0.0231 - val_accuracy: 0.7935 - val_f1_score_metric: 0.7979 - val_get_roc_auc: 0.9945 - val_loss: 1.4490
# Epoch 55/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.9007 - f1_score_metric: 0.9897 - get_roc_auc: 0.9945 - loss: 0.0230
# Epoch 55: val_get_roc_auc improved from 0.99452 to 0.99453, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 113ms/step - accuracy: 0.9007 - f1_score_metric: 0.9897 - get_roc_auc: 0.9945 - loss: 0.0230 - val_accuracy: 0.7768 - val_f1_score_metric: 0.7971 - val_get_roc_auc: 0.9945 - val_loss: 1.4587
# Epoch 56/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.8848 - f1_score_metric: 0.9896 - get_roc_auc: 0.9945 - loss: 0.0232
# Epoch 56: val_get_roc_auc improved from 0.99453 to 0.99454, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 5s 118ms/step - accuracy: 0.8849 - f1_score_metric: 0.9896 - get_roc_auc: 0.9945 - loss: 0.0232 - val_accuracy: 0.7793 - val_f1_score_metric: 0.7985 - val_get_roc_auc: 0.9945 - val_loss: 1.4319
# Epoch 57/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.8960 - f1_score_metric: 0.9897 - get_roc_auc: 0.9946 - loss: 0.0230
# Epoch 57: val_get_roc_auc improved from 0.99454 to 0.99456, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 5s 130ms/step - accuracy: 0.8960 - f1_score_metric: 0.9897 - get_roc_auc: 0.9946 - loss: 0.0230 - val_accuracy: 0.7768 - val_f1_score_metric: 0.7943 - val_get_roc_auc: 0.9946 - val_loss: 1.4888
# Epoch 58/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.8886 - f1_score_metric: 0.9902 - get_roc_auc: 0.9946 - loss: 0.0229
# Epoch 58: val_get_roc_auc improved from 0.99456 to 0.99456, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - accuracy: 0.8886 - f1_score_metric: 0.9902 - get_roc_auc: 0.9946 - loss: 0.0229 - val_accuracy: 0.7824 - val_f1_score_metric: 0.7990 - val_get_roc_auc: 0.9946 - val_loss: 1.5207
# Epoch 59/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.8990 - f1_score_metric: 0.9899 - get_roc_auc: 0.9946 - loss: 0.0228
# Epoch 59: val_get_roc_auc improved from 0.99456 to 0.99457, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 123ms/step - accuracy: 0.8990 - f1_score_metric: 0.9899 - get_roc_auc: 0.9946 - loss: 0.0228 - val_accuracy: 0.7836 - val_f1_score_metric: 0.7909 - val_get_roc_auc: 0.9946 - val_loss: 1.5499
# Epoch 60/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.9064 - f1_score_metric: 0.9899 - get_roc_auc: 0.9946 - loss: 0.0227
# Epoch 60: val_get_roc_auc improved from 0.99457 to 0.99458, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - accuracy: 0.9065 - f1_score_metric: 0.9899 - get_roc_auc: 0.9946 - loss: 0.0227 - val_accuracy: 0.8083 - val_f1_score_metric: 0.7958 - val_get_roc_auc: 0.9946 - val_loss: 1.5029
# Epoch 61/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.9050 - f1_score_metric: 0.9897 - get_roc_auc: 0.9946 - loss: 0.0238
# Epoch 61: val_get_roc_auc improved from 0.99458 to 0.99459, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - accuracy: 0.9050 - f1_score_metric: 0.9897 - get_roc_auc: 0.9946 - loss: 0.0238 - val_accuracy: 0.8243 - val_f1_score_metric: 0.8026 - val_get_roc_auc: 0.9946 - val_loss: 1.4074
# Epoch 62/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.8968 - f1_score_metric: 0.9894 - get_roc_auc: 0.9946 - loss: 0.0238
# Epoch 62: val_get_roc_auc improved from 0.99459 to 0.99460, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 129ms/step - accuracy: 0.8966 - f1_score_metric: 0.9894 - get_roc_auc: 0.9946 - loss: 0.0238 - val_accuracy: 0.7762 - val_f1_score_metric: 0.7953 - val_get_roc_auc: 0.9946 - val_loss: 1.3668
# Epoch 63/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.8896 - f1_score_metric: 0.9897 - get_roc_auc: 0.9946 - loss: 0.0238
# Epoch 63: val_get_roc_auc improved from 0.99460 to 0.99461, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - accuracy: 0.8896 - f1_score_metric: 0.9897 - get_roc_auc: 0.9946 - loss: 0.0238 - val_accuracy: 0.8015 - val_f1_score_metric: 0.7944 - val_get_roc_auc: 0.9946 - val_loss: 1.4866
# Epoch 64/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.8954 - f1_score_metric: 0.9898 - get_roc_auc: 0.9946 - loss: 0.0235
# Epoch 64: val_get_roc_auc improved from 0.99461 to 0.99461, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - accuracy: 0.8954 - f1_score_metric: 0.9898 - get_roc_auc: 0.9946 - loss: 0.0235 - val_accuracy: 0.8471 - val_f1_score_metric: 0.8027 - val_get_roc_auc: 0.9946 - val_loss: 1.4936
# Epoch 65/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.9049 - f1_score_metric: 0.9899 - get_roc_auc: 0.9946 - loss: 0.0225
# Epoch 65: val_get_roc_auc improved from 0.99461 to 0.99462, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 124ms/step - accuracy: 0.9048 - f1_score_metric: 0.9899 - get_roc_auc: 0.9946 - loss: 0.0225 - val_accuracy: 0.7873 - val_f1_score_metric: 0.7954 - val_get_roc_auc: 0.9946 - val_loss: 1.4746
# Epoch 66/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.8829 - f1_score_metric: 0.9902 - get_roc_auc: 0.9946 - loss: 0.0226
# Epoch 66: val_get_roc_auc improved from 0.99462 to 0.99463, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - accuracy: 0.8831 - f1_score_metric: 0.9902 - get_roc_auc: 0.9946 - loss: 0.0226 - val_accuracy: 0.8150 - val_f1_score_metric: 0.7981 - val_get_roc_auc: 0.9946 - val_loss: 1.4801
# Epoch 67/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.8950 - f1_score_metric: 0.9898 - get_roc_auc: 0.9946 - loss: 0.0232
# Epoch 67: val_get_roc_auc improved from 0.99463 to 0.99464, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 5s 115ms/step - accuracy: 0.8951 - f1_score_metric: 0.9898 - get_roc_auc: 0.9946 - loss: 0.0232 - val_accuracy: 0.8311 - val_f1_score_metric: 0.7975 - val_get_roc_auc: 0.9946 - val_loss: 1.4762
# Epoch 68/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9032 - f1_score_metric: 0.9899 - get_roc_auc: 0.9946 - loss: 0.0231
# Epoch 68: val_get_roc_auc improved from 0.99464 to 0.99465, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.9031 - f1_score_metric: 0.9899 - get_roc_auc: 0.9947 - loss: 0.0231 - val_accuracy: 0.7824 - val_f1_score_metric: 0.7935 - val_get_roc_auc: 0.9946 - val_loss: 1.4539
# Epoch 69/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.8886 - f1_score_metric: 0.9895 - get_roc_auc: 0.9947 - loss: 0.0237
# Epoch 69: val_get_roc_auc improved from 0.99465 to 0.99465, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - accuracy: 0.8886 - f1_score_metric: 0.9895 - get_roc_auc: 0.9947 - loss: 0.0237 - val_accuracy: 0.8249 - val_f1_score_metric: 0.8002 - val_get_roc_auc: 0.9947 - val_loss: 1.4907
# Epoch 70/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.8958 - f1_score_metric: 0.9900 - get_roc_auc: 0.9947 - loss: 0.0228
# Epoch 70: val_get_roc_auc improved from 0.99465 to 0.99466, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 5s 117ms/step - accuracy: 0.8958 - f1_score_metric: 0.9900 - get_roc_auc: 0.9947 - loss: 0.0228 - val_accuracy: 0.8187 - val_f1_score_metric: 0.8065 - val_get_roc_auc: 0.9947 - val_loss: 1.5090
# Epoch 71/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.8993 - f1_score_metric: 0.9898 - get_roc_auc: 0.9947 - loss: 0.0228
# Epoch 71: val_get_roc_auc improved from 0.99466 to 0.99466, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 5s 127ms/step - accuracy: 0.8992 - f1_score_metric: 0.9898 - get_roc_auc: 0.9947 - loss: 0.0228 - val_accuracy: 0.7657 - val_f1_score_metric: 0.8024 - val_get_roc_auc: 0.9947 - val_loss: 1.5257
# Epoch 72/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.8880 - f1_score_metric: 0.9897 - get_roc_auc: 0.9947 - loss: 0.0240
# Epoch 72: val_get_roc_auc improved from 0.99466 to 0.99466, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - accuracy: 0.8881 - f1_score_metric: 0.9897 - get_roc_auc: 0.9947 - loss: 0.0240 - val_accuracy: 0.7978 - val_f1_score_metric: 0.7994 - val_get_roc_auc: 0.9947 - val_loss: 1.5091
# Epoch 73/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.8839 - f1_score_metric: 0.9893 - get_roc_auc: 0.9947 - loss: 0.0240
# Epoch 73: val_get_roc_auc improved from 0.99466 to 0.99467, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - accuracy: 0.8840 - f1_score_metric: 0.9893 - get_roc_auc: 0.9947 - loss: 0.0240 - val_accuracy: 0.7700 - val_f1_score_metric: 0.7952 - val_get_roc_auc: 0.9947 - val_loss: 1.4846
# Epoch 74/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.8905 - f1_score_metric: 0.9894 - get_roc_auc: 0.9947 - loss: 0.0244
# Epoch 74: val_get_roc_auc improved from 0.99467 to 0.99467, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 5s 126ms/step - accuracy: 0.8905 - f1_score_metric: 0.9895 - get_roc_auc: 0.9947 - loss: 0.0244 - val_accuracy: 0.8175 - val_f1_score_metric: 0.7982 - val_get_roc_auc: 0.9947 - val_loss: 1.4940
# Epoch 75/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.8963 - f1_score_metric: 0.9896 - get_roc_auc: 0.9947 - loss: 0.0239
# Epoch 75: val_get_roc_auc improved from 0.99467 to 0.99468, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - accuracy: 0.8963 - f1_score_metric: 0.9896 - get_roc_auc: 0.9947 - loss: 0.0240 - val_accuracy: 0.8527 - val_f1_score_metric: 0.7962 - val_get_roc_auc: 0.9947 - val_loss: 1.5464
# Epoch 76/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.9031 - f1_score_metric: 0.9898 - get_roc_auc: 0.9947 - loss: 0.0238
# Epoch 76: val_get_roc_auc improved from 0.99468 to 0.99468, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 5s 115ms/step - accuracy: 0.9031 - f1_score_metric: 0.9898 - get_roc_auc: 0.9947 - loss: 0.0238 - val_accuracy: 0.8459 - val_f1_score_metric: 0.7753 - val_get_roc_auc: 0.9947 - val_loss: 1.7804
# Epoch 77/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.9075 - f1_score_metric: 0.9892 - get_roc_auc: 0.9947 - loss: 0.0252
# Epoch 77: val_get_roc_auc improved from 0.99468 to 0.99469, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 5s 116ms/step - accuracy: 0.9074 - f1_score_metric: 0.9892 - get_roc_auc: 0.9947 - loss: 0.0252 - val_accuracy: 0.8477 - val_f1_score_metric: 0.7954 - val_get_roc_auc: 0.9947 - val_loss: 1.5716
# Epoch 78/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.8906 - f1_score_metric: 0.9894 - get_roc_auc: 0.9947 - loss: 0.0245
# Epoch 78: val_get_roc_auc improved from 0.99469 to 0.99469, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 5s 116ms/step - accuracy: 0.8907 - f1_score_metric: 0.9894 - get_roc_auc: 0.9947 - loss: 0.0244 - val_accuracy: 0.7996 - val_f1_score_metric: 0.7947 - val_get_roc_auc: 0.9947 - val_loss: 1.5182
# Epoch 79/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.8865 - f1_score_metric: 0.9894 - get_roc_auc: 0.9947 - loss: 0.0243
# Epoch 79: val_get_roc_auc improved from 0.99469 to 0.99470, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - accuracy: 0.8867 - f1_score_metric: 0.9894 - get_roc_auc: 0.9947 - loss: 0.0243 - val_accuracy: 0.7787 - val_f1_score_metric: 0.8004 - val_get_roc_auc: 0.9947 - val_loss: 1.4654
# Epoch 80/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.8938 - f1_score_metric: 0.9894 - get_roc_auc: 0.9947 - loss: 0.0238
# Epoch 80: val_get_roc_auc improved from 0.99470 to 0.99470, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - accuracy: 0.8938 - f1_score_metric: 0.9894 - get_roc_auc: 0.9947 - loss: 0.0238 - val_accuracy: 0.7552 - val_f1_score_metric: 0.7958 - val_get_roc_auc: 0.9947 - val_loss: 1.5045
# Epoch 81/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.8945 - f1_score_metric: 0.9894 - get_roc_auc: 0.9947 - loss: 0.0243
# Epoch 81: val_get_roc_auc improved from 0.99470 to 0.99470, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 5s 116ms/step - accuracy: 0.8947 - f1_score_metric: 0.9894 - get_roc_auc: 0.9947 - loss: 0.0242 - val_accuracy: 0.8015 - val_f1_score_metric: 0.7984 - val_get_roc_auc: 0.9947 - val_loss: 1.5476
# Epoch 82/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.9004 - f1_score_metric: 0.9899 - get_roc_auc: 0.9947 - loss: 0.0231
# Epoch 82: val_get_roc_auc improved from 0.99470 to 0.99470, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - accuracy: 0.9004 - f1_score_metric: 0.9899 - get_roc_auc: 0.9947 - loss: 0.0231 - val_accuracy: 0.8101 - val_f1_score_metric: 0.7947 - val_get_roc_auc: 0.9947 - val_loss: 1.5259
# Epoch 83/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.9012 - f1_score_metric: 0.9902 - get_roc_auc: 0.9947 - loss: 0.0220
# Epoch 83: val_get_roc_auc improved from 0.99470 to 0.99471, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 119ms/step - accuracy: 0.9012 - f1_score_metric: 0.9902 - get_roc_auc: 0.9947 - loss: 0.0220 - val_accuracy: 0.7861 - val_f1_score_metric: 0.7906 - val_get_roc_auc: 0.9947 - val_loss: 1.6432
# Epoch 84/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.8931 - f1_score_metric: 0.9902 - get_roc_auc: 0.9947 - loss: 0.0216
# Epoch 84: val_get_roc_auc improved from 0.99471 to 0.99471, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 5s 115ms/step - accuracy: 0.8933 - f1_score_metric: 0.9902 - get_roc_auc: 0.9947 - loss: 0.0216 - val_accuracy: 0.8385 - val_f1_score_metric: 0.7965 - val_get_roc_auc: 0.9947 - val_loss: 1.6936
# Epoch 85/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.9131 - f1_score_metric: 0.9904 - get_roc_auc: 0.9947 - loss: 0.0219
# Epoch 85: val_get_roc_auc improved from 0.99471 to 0.99471, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.9130 - f1_score_metric: 0.9904 - get_roc_auc: 0.9947 - loss: 0.0219 - val_accuracy: 0.8298 - val_f1_score_metric: 0.7954 - val_get_roc_auc: 0.9947 - val_loss: 1.7916
# Epoch 86/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.9030 - f1_score_metric: 0.9901 - get_roc_auc: 0.9947 - loss: 0.0215
# Epoch 86: val_get_roc_auc improved from 0.99471 to 0.99471, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 5s 115ms/step - accuracy: 0.9029 - f1_score_metric: 0.9901 - get_roc_auc: 0.9947 - loss: 0.0216 - val_accuracy: 0.7990 - val_f1_score_metric: 0.7941 - val_get_roc_auc: 0.9947 - val_loss: 1.7494
# Epoch 87/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.9121 - f1_score_metric: 0.9901 - get_roc_auc: 0.9947 - loss: 0.0215
# Epoch 87: val_get_roc_auc improved from 0.99471 to 0.99471, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 5s 126ms/step - accuracy: 0.9120 - f1_score_metric: 0.9901 - get_roc_auc: 0.9947 - loss: 0.0215 - val_accuracy: 0.8052 - val_f1_score_metric: 0.7890 - val_get_roc_auc: 0.9947 - val_loss: 1.7098
# Epoch 88/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.8989 - f1_score_metric: 0.9903 - get_roc_auc: 0.9947 - loss: 0.0216
# Epoch 88: val_get_roc_auc improved from 0.99471 to 0.99472, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 5s 127ms/step - accuracy: 0.8990 - f1_score_metric: 0.9903 - get_roc_auc: 0.9947 - loss: 0.0216 - val_accuracy: 0.7861 - val_f1_score_metric: 0.7961 - val_get_roc_auc: 0.9947 - val_loss: 1.8026
# Epoch 89/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.9012 - f1_score_metric: 0.9901 - get_roc_auc: 0.9947 - loss: 0.0214
# Epoch 89: val_get_roc_auc improved from 0.99472 to 0.99472, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 5s 114ms/step - accuracy: 0.9014 - f1_score_metric: 0.9901 - get_roc_auc: 0.9947 - loss: 0.0214 - val_accuracy: 0.8144 - val_f1_score_metric: 0.7947 - val_get_roc_auc: 0.9947 - val_loss: 1.8296
# Epoch 90/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.9043 - f1_score_metric: 0.9902 - get_roc_auc: 0.9947 - loss: 0.0214
# Epoch 90: val_get_roc_auc improved from 0.99472 to 0.99472, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 5s 116ms/step - accuracy: 0.9044 - f1_score_metric: 0.9902 - get_roc_auc: 0.9947 - loss: 0.0214 - val_accuracy: 0.8311 - val_f1_score_metric: 0.7922 - val_get_roc_auc: 0.9947 - val_loss: 1.8782
# Epoch 91/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9132 - f1_score_metric: 0.9903 - get_roc_auc: 0.9947 - loss: 0.0214
# Epoch 91: val_get_roc_auc improved from 0.99472 to 0.99472, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 5s 117ms/step - accuracy: 0.9131 - f1_score_metric: 0.9903 - get_roc_auc: 0.9947 - loss: 0.0214 - val_accuracy: 0.8440 - val_f1_score_metric: 0.7931 - val_get_roc_auc: 0.9947 - val_loss: 1.8945
# Epoch 92/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.9184 - f1_score_metric: 0.9903 - get_roc_auc: 0.9947 - loss: 0.0213
# Epoch 92: val_get_roc_auc improved from 0.99472 to 0.99472, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 5s 114ms/step - accuracy: 0.9184 - f1_score_metric: 0.9903 - get_roc_auc: 0.9947 - loss: 0.0213 - val_accuracy: 0.8409 - val_f1_score_metric: 0.7912 - val_get_roc_auc: 0.9947 - val_loss: 1.9383
# Epoch 93/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.9197 - f1_score_metric: 0.9904 - get_roc_auc: 0.9947 - loss: 0.0215
# Epoch 93: val_get_roc_auc improved from 0.99472 to 0.99472, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - accuracy: 0.9198 - f1_score_metric: 0.9904 - get_roc_auc: 0.9947 - loss: 0.0215 - val_accuracy: 0.8403 - val_f1_score_metric: 0.7934 - val_get_roc_auc: 0.9947 - val_loss: 1.8710
# Epoch 94/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9251 - f1_score_metric: 0.9904 - get_roc_auc: 0.9947 - loss: 0.0211
# Epoch 94: val_get_roc_auc improved from 0.99472 to 0.99472, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - accuracy: 0.9250 - f1_score_metric: 0.9904 - get_roc_auc: 0.9947 - loss: 0.0211 - val_accuracy: 0.8169 - val_f1_score_metric: 0.7911 - val_get_roc_auc: 0.9947 - val_loss: 1.9067
# Epoch 95/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.9248 - f1_score_metric: 0.9902 - get_roc_auc: 0.9947 - loss: 0.0214
# Epoch 95: val_get_roc_auc improved from 0.99472 to 0.99472, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - accuracy: 0.9248 - f1_score_metric: 0.9902 - get_roc_auc: 0.9947 - loss: 0.0214 - val_accuracy: 0.7996 - val_f1_score_metric: 0.7910 - val_get_roc_auc: 0.9947 - val_loss: 1.8355
# Epoch 96/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.9042 - f1_score_metric: 0.9902 - get_roc_auc: 0.9947 - loss: 0.0218
# Epoch 96: val_get_roc_auc did not improve from 0.99472
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.9044 - f1_score_metric: 0.9902 - get_roc_auc: 0.9947 - loss: 0.0218 - val_accuracy: 0.8280 - val_f1_score_metric: 0.7967 - val_get_roc_auc: 0.9947 - val_loss: 1.8811
# Epoch 97/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.9069 - f1_score_metric: 0.9903 - get_roc_auc: 0.9947 - loss: 0.0212
# Epoch 97: val_get_roc_auc improved from 0.99472 to 0.99472, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 5s 127ms/step - accuracy: 0.9071 - f1_score_metric: 0.9903 - get_roc_auc: 0.9947 - loss: 0.0212 - val_accuracy: 0.8613 - val_f1_score_metric: 0.8000 - val_get_roc_auc: 0.9947 - val_loss: 1.9242
# Epoch 98/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.9224 - f1_score_metric: 0.9901 - get_roc_auc: 0.9947 - loss: 0.0218
# Epoch 98: val_get_roc_auc improved from 0.99472 to 0.99472, saving model to model-lstm.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - accuracy: 0.9222 - f1_score_metric: 0.9901 - get_roc_auc: 0.9947 - loss: 0.0218 - val_accuracy: 0.8218 - val_f1_score_metric: 0.7939 - val_get_roc_auc: 0.9947 - val_loss: 1.8733
# Epoch 99/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.9167 - f1_score_metric: 0.9902 - get_roc_auc: 0.9947 - loss: 0.0217
# Epoch 99: val_get_roc_auc did not improve from 0.99472
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 96ms/step - accuracy: 0.9169 - f1_score_metric: 0.9902 - get_roc_auc: 0.9947 - loss: 0.0217 - val_accuracy: 0.8446 - val_f1_score_metric: 0.7954 - val_get_roc_auc: 0.9947 - val_loss: 1.8575
# Epoch 100/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9297 - f1_score_metric: 0.9902 - get_roc_auc: 0.9947 - loss: 0.0218
# Epoch 100: val_get_roc_auc did not improve from 0.99472
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 5s 98ms/step - accuracy: 0.9296 - f1_score_metric: 0.9902 - get_roc_auc: 0.9947 - loss: 0.0218 - val_accuracy: 0.8422 - val_f1_score_metric: 0.7908 - val_get_roc_auc: 0.9947 - val_loss: 1.8773
# --- 485.61635851860046 seconds ---

# %% [markdown]
# Bidirectional GRU Model

# %%
from keras.layers import Dense, Input, GRU, Bidirectional, Embedding, Dropout
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.layers import GlobalMaxPool1D
from keras.optimizers import Adam
from keras.models import Model
import tensorflow as tf
import numpy as np
import random
import time

# fix seeds for re-producability
np.random.seed(7)
tf.random.set_seed(7)
random.seed(7)

def get_f1(actual, predicted):
  TP = tf.math.count_nonzero(predicted * actual) # Use tf.math.count_nonzero
  TN = tf.math.count_nonzero((predicted - 1) * (actual - 1)) # Use tf.math.count_nonzero
  FP = tf.math.count_nonzero(predicted * (actual - 1)) # Use tf.math.count_nonzero
  FN = tf.math.count_nonzero((predicted - 1) * actual) # Use tf.math.count_nonzero

  precision = tf.divide(TP, TP + FP)
  recall = tf.divide(TP, TP + FN)

  f1 = tf.divide(2 * precision * recall, precision + recall)

  return f1

def f1_score_metric(actual, predicted):
  predicted = tf.cast(predicted>=0.5, tf.int32) # Use tf.cast for type conversion
  actual = tf.cast(actual, tf.int32) # Use tf.cast for type conversion

  new_overall_f1_weighted = 0

  for class_id in range(0, 6):

    # F1 score
    f1 = get_f1(actual=actual[:, class_id], predicted=predicted[:, class_id])

    new_overall_f1_weighted += f1 * class_percentage[class_id]


  return new_overall_f1_weighted/target


start_time = time.time()

TRAIN_DATA_FILE = "/content/drive/My Drive/toxic-comments-classification/toxicity-types-data/training-data-tokenized.csv"
VALIDATION_DATA_FILE = "/content/drive/My Drive/toxic-comments-classification/toxicity-types-data/validation-data-tokenized.csv"
EMBEDDING_FILE = "/content/drive/My Drive/toxic-comments-classification/toxicity-types-data/fasttext-embedding-matrix.csv"

# Parameters
max_comment_length = 150
vector_size = 300

# Read data
training_data = np.loadtxt(TRAIN_DATA_FILE, delimiter=',')
print(training_data.shape)

training_input = training_data[:, 0:max_comment_length]
print(training_input.shape)

training_labels = training_data[:, max_comment_length:156]
print(training_labels.shape)

embedding_matrix = np.loadtxt(EMBEDDING_FILE, delimiter=',')
print(embedding_matrix.shape)
vocab_count = embedding_matrix.shape[0]
print(vocab_count)

validation_data = np.loadtxt(VALIDATION_DATA_FILE, delimiter=',')
validation_labels = validation_data[:, max_comment_length:156]

total_records_count = validation_data.shape[0]
class_records_count = np.sum(validation_labels, axis=0)

print(class_records_count)
print(total_records_count)

class_percentage = (class_records_count/total_records_count)
print(class_percentage)

target = np.sum(class_percentage)
print(target)


# Build model
input = Input(shape=(max_comment_length, ))

x = Embedding(input_dim=vocab_count, output_dim=vector_size, weights=[embedding_matrix], trainable=True)(input)

gru_output = Bidirectional(GRU(units=40, activation="tanh", return_sequences=True))(x)

pooling_output = GlobalMaxPool1D()(gru_output)

dense1_output = Dense(80, activation="relu")(pooling_output)
dropout1_output = Dropout(0.2)(dense1_output)

dense2_output = Dense(80, activation="relu")(dropout1_output)
dropout2_output = Dropout(0.2)(dense2_output)

output = Dense(6, activation="sigmoid")(dropout2_output)


# Compile Model
model = Model(inputs=input, outputs=output)
print(model.summary())

model.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate=0.0045), metrics=['accuracy', f1_score_metric])

# Callbacks for early stopping and saving the best model
checkpoint = ModelCheckpoint('model-gru.keras', monitor='val_f1_score_metric', # Changed file extension to .keras
                             verbose=1, save_best_only=True, mode='max')

early_stopping = EarlyStopping(monitor='val_f1_score_metric', patience=5, mode='max')

callbacks_list = [checkpoint, early_stopping]

model.fit(training_input, training_labels, batch_size=1024, epochs=100, callbacks=callbacks_list,
          validation_data=(validation_data[:, 0:max_comment_length], validation_data[:,max_comment_length:156]))

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (36491, 156)
# (36491, 150)
# (36491, 6)
# (29355, 300)
# 29355
# [1531.  148.  850.   54.  833.  142.]
# 1622
# [0.94389642 0.09124538 0.52404439 0.03329223 0.5135635  0.08754624]
# 2.193588162762022
# Model: "functional_20"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_20 (InputLayer)          │ (None, 150)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ embedding_20 (Embedding)             │ (None, 150, 300)            │       8,806,500 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional_20 (Bidirectional)     │ (None, 150, 80)             │          82,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_max_pooling1d_20              │ (None, 80)                  │               0 │
# │ (GlobalMaxPooling1D)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_60 (Dense)                     │ (None, 80)                  │           6,480 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_40 (Dropout)                 │ (None, 80)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_61 (Dense)                     │ (None, 80)                  │           6,480 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_41 (Dropout)                 │ (None, 80)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_62 (Dense)                     │ (None, 6)                   │             486 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 8,902,026 (33.96 MB)
#  Trainable params: 8,902,026 (33.96 MB)
#  Non-trainable params: 0 (0.00 B)
# None
# Epoch 1/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.7796 - f1_score_metric: nan - loss: 0.4599
# Epoch 1: val_f1_score_metric improved from -inf to 0.83336, saving model to model-gru.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 137ms/step - accuracy: 0.7796 - f1_score_metric: nan - loss: 0.4574 - val_accuracy: 0.8989 - val_f1_score_metric: 0.8334 - val_loss: 0.3072
# Epoch 2/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.8090 - f1_score_metric: 0.9330 - loss: 0.2134
# Epoch 2: val_f1_score_metric did not improve from 0.83336
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - accuracy: 0.8087 - f1_score_metric: 0.9332 - loss: 0.2128 - val_accuracy: 0.8878 - val_f1_score_metric: 0.8272 - val_loss: 0.3085
# Epoch 3/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.7742 - f1_score_metric: 0.9585 - loss: 0.1319
# Epoch 3: val_f1_score_metric did not improve from 0.83336
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 95ms/step - accuracy: 0.7739 - f1_score_metric: 0.9586 - loss: 0.1316 - val_accuracy: 0.8656 - val_f1_score_metric: 0.8112 - val_loss: 0.3813
# Epoch 4/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.7768 - f1_score_metric: 0.9708 - loss: 0.0948
# Epoch 4: val_f1_score_metric did not improve from 0.83336
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.7769 - f1_score_metric: 0.9709 - loss: 0.0946 - val_accuracy: 0.7688 - val_f1_score_metric: 0.8309 - val_loss: 0.4335
# Epoch 5/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.7807 - f1_score_metric: 0.9785 - loss: 0.0739
# Epoch 5: val_f1_score_metric did not improve from 0.83336
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 5s 97ms/step - accuracy: 0.7811 - f1_score_metric: 0.9785 - loss: 0.0738 - val_accuracy: 0.8070 - val_f1_score_metric: 0.8252 - val_loss: 0.4897
# Epoch 6/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.7995 - f1_score_metric: 0.9838 - loss: 0.0581
# Epoch 6: val_f1_score_metric did not improve from 0.83336
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.7997 - f1_score_metric: 0.9838 - loss: 0.0580 - val_accuracy: 0.8342 - val_f1_score_metric: 0.8098 - val_loss: 0.5433
# --- 43.38408851623535 seconds ---

# %% [markdown]
# Bidirectional CNN

# %%
from keras.layers import Dense, Input, Conv2D, Embedding, Dropout, Reshape, Flatten, Lambda, concatenate
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.layers import GlobalMaxPool2D
from keras.optimizers import Adam
from keras.models import Model
import keras.backend as K
import tensorflow as tf
import numpy as np
import random
import time

# fix seeds for re-producability
np.random.seed(7)
tf.random.set_seed(7)
random.seed(7)

def get_f1(actual, predicted):
  TP = tf.math.count_nonzero(predicted * actual) # Use tf.math.count_nonzero
  TN = tf.math.count_nonzero((predicted - 1) * (actual - 1)) # Use tf.math.count_nonzero
  FP = tf.math.count_nonzero(predicted * (actual - 1)) # Use tf.math.count_nonzero
  FN = tf.math.count_nonzero((predicted - 1) * actual) # Use tf.math.count_nonzero

  precision = tf.divide(TP, TP + FP)
  recall = tf.divide(TP, TP + FN)

  f1 = tf.divide(2 * precision * recall, precision + recall)

  return f1

def f1_score_metric(actual, predicted):
  predicted = tf.cast(predicted>=0.5, tf.int32) # Use tf.cast for type conversion
  actual = tf.cast(actual, tf.int32) # Use tf.cast for type conversion

  new_overall_f1_weighted = 0

  for class_id in range(0, 6):

    # F1 score
    f1 = get_f1(actual=actual[:, class_id], predicted=predicted[:, class_id])

    new_overall_f1_weighted += f1 * class_percentage[class_id]


  return new_overall_f1_weighted/target

def flip(x):
  return tf.reverse(x, axis=[1]) # Use tf.reverse instead of k.reverse

start_time = time.time()

TRAIN_DATA_FILE = "/content/drive/My Drive/toxic-comments-classification/toxicity-types-data/training-data-tokenized.csv"
VALIDATION_DATA_FILE = "/content/drive/My Drive/toxic-comments-classification/toxicity-types-data/validation-data-tokenized.csv"
EMBEDDING_FILE = "/content/drive/My Drive/toxic-comments-classification/toxicity-types-data/fasttext-embedding-matrix.csv"

# Parameters
max_comment_length = 150
vector_size = 300

# Read data
training_data = np.loadtxt(TRAIN_DATA_FILE, delimiter=',')
print(training_data.shape)

training_input = training_data[:, 0:max_comment_length]
print(training_input.shape)

training_labels = training_data[:, max_comment_length:156]
print(training_labels.shape)

embedding_matrix = np.loadtxt(EMBEDDING_FILE, delimiter=',')
print(embedding_matrix.shape)
vocab_count = embedding_matrix.shape[0]
print(vocab_count)

validation_data = np.loadtxt(VALIDATION_DATA_FILE, delimiter=',')
validation_labels = validation_data[:, max_comment_length:156]

total_records_count = validation_data.shape[0]
class_records_count = np.sum(validation_labels, axis=0)

print(class_records_count)
print(total_records_count)

class_percentage = (class_records_count/total_records_count)
print(class_percentage)

target = np.sum(class_percentage)
print(target)

# Build model

layer = Lambda(flip, output_shape=(150, 300, 1))

input = Input(shape=(max_comment_length, ))

x = Embedding(input_dim=vocab_count, output_dim=vector_size, weights=[embedding_matrix], trainable=True)(input)

x_reshaped = Reshape((150, 300, 1))(x)

# Define the output shape for the Lambda layer
layer = Lambda(flip, output_shape=(150, 300, 1))

cnn_output1 = Conv2D(filters=200, kernel_size=(8,300), activation='relu', data_format="channels_last")(x_reshaped)
cnn_output2 = Conv2D(filters=200, kernel_size=(8,300), activation='relu', data_format="channels_last")(layer(x_reshaped))

pooling_output1 = GlobalMaxPool2D()(cnn_output1)
pooling_output2 = GlobalMaxPool2D()(cnn_output2)

pooling_output_merged = concatenate([pooling_output1, pooling_output2])

dense1_output = Dense(50, activation="relu")(pooling_output_merged)
dropout1_output = Dropout(0.2)(dense1_output)
output = Dense(6, activation="sigmoid")(dropout1_output)

# Compile Model
model = Model(inputs=input, outputs=output)
print(model.summary())

model.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate=0.0005), metrics=['accuracy', f1_score_metric])

# Callbacks for early stopping and saving the best model
checkpoint = ModelCheckpoint('model-cnn-bidirectional.keras', monitor='val_f1_score_metric', # Changed file extension to .keras
                             verbose=1, save_best_only=True, mode='max')

early_stopping = EarlyStopping(monitor='val_f1_score_metric', patience=5, mode='max')

callbacks_list = [checkpoint, early_stopping]

model.fit(training_input, training_labels, batch_size=1024, epochs=100, callbacks=callbacks_list,
          validation_data=(validation_data[:, 0:max_comment_length], validation_data[:,max_comment_length:156]))


print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (36491, 156)
# (36491, 150)
# (36491, 6)
# (29355, 300)
# 29355
# [1531.  148.  850.   54.  833.  142.]
# 1622
# [0.94389642 0.09124538 0.52404439 0.03329223 0.5135635  0.08754624]
# 2.193588162762022
# Model: "functional_26"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_28            │ (None, 150)            │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ embedding_28 (Embedding)  │ (None, 150, 300)       │      8,806,500 │ input_layer_28[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_7 (Reshape)       │ (None, 150, 300, 1)    │              0 │ embedding_28[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_13 (Lambda)        │ (None, 150, 300, 1)    │              0 │ reshape_7[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_14 (Conv2D)        │ (None, 143, 1, 200)    │        480,200 │ reshape_7[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_15 (Conv2D)        │ (None, 143, 1, 200)    │        480,200 │ lambda_13[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_max_pooling2d_10   │ (None, 200)            │              0 │ conv2d_14[0][0]        │
# │ (GlobalMaxPooling2D)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_max_pooling2d_11   │ (None, 200)            │              0 │ conv2d_15[0][0]        │
# │ (GlobalMaxPooling2D)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_5             │ (None, 400)            │              0 │ global_max_pooling2d_… │
# │ (Concatenate)             │                        │                │ global_max_pooling2d_… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_73 (Dense)          │ (None, 50)             │         20,050 │ concatenate_5[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_47 (Dropout)      │ (None, 50)             │              0 │ dense_73[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_74 (Dense)          │ (None, 6)              │            306 │ dropout_47[0][0]       │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 9,787,256 (37.34 MB)
#  Trainable params: 9,787,256 (37.34 MB)
#  Non-trainable params: 0 (0.00 B)
# None
# Epoch 1/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.8785 - f1_score_metric: nan - loss: 0.5134
# Epoch 1: val_f1_score_metric improved from -inf to 0.82028, saving model to model-cnn-bidirectional.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 431s 5s/step - accuracy: 0.8774 - f1_score_metric: nan - loss: 0.5112 - val_accuracy: 0.8859 - val_f1_score_metric: 0.8203 - val_loss: 0.3458
# Epoch 2/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.6847 - f1_score_metric: 0.9008 - loss: 0.3119
# Epoch 2: val_f1_score_metric improved from 0.82028 to 0.83615, saving model to model-cnn-bidirectional.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 365ms/step - accuracy: 0.6849 - f1_score_metric: 0.9010 - loss: 0.3114 - val_accuracy: 0.8773 - val_f1_score_metric: 0.8362 - val_loss: 0.3128
# Epoch 3/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - accuracy: 0.6904 - f1_score_metric: 0.9255 - loss: 0.2471
# Epoch 3: val_f1_score_metric improved from 0.83615 to 0.84396, saving model to model-cnn-bidirectional.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 368ms/step - accuracy: 0.6907 - f1_score_metric: 0.9256 - loss: 0.2468 - val_accuracy: 0.8792 - val_f1_score_metric: 0.8440 - val_loss: 0.2993
# Epoch 4/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.6932 - f1_score_metric: 0.9391 - loss: 0.2059
# Epoch 4: val_f1_score_metric improved from 0.84396 to 0.84456, saving model to model-cnn-bidirectional.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 20s 365ms/step - accuracy: 0.6936 - f1_score_metric: 0.9391 - loss: 0.2057 - val_accuracy: 0.8761 - val_f1_score_metric: 0.8446 - val_loss: 0.2932
# Epoch 5/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.7116 - f1_score_metric: 0.9491 - loss: 0.1748
# Epoch 5: val_f1_score_metric did not improve from 0.84456
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 20s 338ms/step - accuracy: 0.7118 - f1_score_metric: 0.9492 - loss: 0.1746 - val_accuracy: 0.8631 - val_f1_score_metric: 0.8408 - val_loss: 0.2955
# Epoch 6/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.7128 - f1_score_metric: 0.9572 - loss: 0.1494
# Epoch 6: val_f1_score_metric did not improve from 0.84456
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 20s 337ms/step - accuracy: 0.7131 - f1_score_metric: 0.9572 - loss: 0.1493 - val_accuracy: 0.8502 - val_f1_score_metric: 0.8403 - val_loss: 0.3022
# Epoch 7/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.7220 - f1_score_metric: 0.9639 - loss: 0.1282
# Epoch 7: val_f1_score_metric did not improve from 0.84456
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 12s 341ms/step - accuracy: 0.7222 - f1_score_metric: 0.9639 - loss: 0.1281 - val_accuracy: 0.8163 - val_f1_score_metric: 0.8362 - val_loss: 0.3132
# Epoch 8/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.7156 - f1_score_metric: 0.9696 - loss: 0.1097
# Epoch 8: val_f1_score_metric did not improve from 0.84456
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 12s 342ms/step - accuracy: 0.7159 - f1_score_metric: 0.9696 - loss: 0.1096 - val_accuracy: 0.8434 - val_f1_score_metric: 0.8342 - val_loss: 0.3274
# Epoch 9/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.7327 - f1_score_metric: 0.9745 - loss: 0.0954
# Epoch 9: val_f1_score_metric did not improve from 0.84456
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 20s 339ms/step - accuracy: 0.7325 - f1_score_metric: 0.9745 - loss: 0.0954 - val_accuracy: 0.8249 - val_f1_score_metric: 0.8301 - val_loss: 0.3440
# --- 595.2458162307739 seconds ---

# %% [markdown]
# Merge different kernel sizes in CNN

# %%
from keras.layers import Dense, Input, Conv2D, Embedding, Dropout, Reshape, Flatten, Lambda, concatenate
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.layers import GlobalMaxPool2D
from keras.optimizers import Adam
from keras.models import Model
import keras.backend as K
import tensorflow as tf
import numpy as np
import random
import time

# fix seeds for re-producability
np.random.seed(7)
tf.random.set_seed(7)
random.seed(7)

def get_f1(actual, predicted):
  TP = tf.count_nonzero(predicted * actual)
  TN = tf.count_nonzero((predicted - 1) * (actual - 1))
  FP = tf.count_nonzero(predicted * (actual - 1))
  FN = tf.count_nonzero((predicted - 1) * actual)

  precision = tf.divide(TP, TP + FP)
  recall = tf.divide(TP, TP + FN)

  f1 = tf.divide(2 * precision * recall, precision + recall)

  return f1

def f1_score_metric(actual, predicted):
  predicted = tf.to_int32(predicted>=0.5)
  actual = tf.to_int32(actual)

  new_overall_f1_weighted = 0

  for class_id in range(0, 6):

    # F1 score
    f1 = get_f1(actual=actual[:, class_id], predicted=predicted[:, class_id])

    new_overall_f1_weighted += f1 * class_percentage[class_id]


  return new_overall_f1_weighted/target

start_time = time.time()

# TRAIN_DATA_FILE = "drive/toxicity type classifier/training-data-tokenized-augemented.csv"
# VALIDATION_DATA_FILE = "drive/toxicity type classifier/validation-data-tokenized.csv"
# EMBEDDING_FILE = "drive/toxicity type classifier/fasttext-embedding-matrix.csv"

TRAIN_DATA_FILE = "/content/drive/My Drive/toxic-comments-classification/toxicity-types-data/training-data-tokenized-augmented.csv"
VALIDATION_DATA_FILE = "/content/drive/My Drive/toxic-comments-classification/toxicity-types-data/validation-data-tokenized.csv"
EMBEDDING_FILE = "/content/drive/My Drive/toxic-comments-classification/toxicity-types-data/fasttext-embedding-matrix.csv"


# Parameters
max_comment_length = 150
vector_size = 300

# Read data
training_data = np.loadtxt(TRAIN_DATA_FILE, delimiter=',')
print(training_data.shape)

training_input = training_data[:, 0:max_comment_length]
print(training_input.shape)

training_labels = training_data[:, max_comment_length:156]
print(training_labels.shape)

embedding_matrix = np.loadtxt(EMBEDDING_FILE, delimiter=',')
print(embedding_matrix.shape)
vocab_count = embedding_matrix.shape[0]
print(vocab_count)

validation_data = np.loadtxt(VALIDATION_DATA_FILE, delimiter=',')
validation_labels = validation_data[:, max_comment_length:156]

total_records_count = validation_data.shape[0]
class_records_count = np.sum(validation_labels, axis=0)

print(class_records_count)
print(total_records_count)

class_percentage = (class_records_count/total_records_count)
print(class_percentage)

target = np.sum(class_percentage)
print(target)

# Build model

input = Input(shape=(max_comment_length, ))

x = Embedding(input_dim=vocab_count, output_dim=vector_size, weights=[embedding_matrix], trainable=True)(input)

x_reshaped = Reshape((150, 300, 1))(x)

cnn_output1 = Conv2D(filters=300, kernel_size=(2,300), activation='relu', data_format="channels_last")(x_reshaped)
cnn_output2 = Conv2D(filters=300, kernel_size=(4,300), activation='relu', data_format="channels_last")(x_reshaped)
cnn_output3 = Conv2D(filters=300, kernel_size=(6,300), activation='relu', data_format="channels_last")(x_reshaped)
cnn_output4 = Conv2D(filters=300, kernel_size=(8,300), activation='relu', data_format="channels_last")(x_reshaped)


pooling_output1 = GlobalMaxPool2D()(cnn_output1)
pooling_output2 = GlobalMaxPool2D()(cnn_output2)
pooling_output3 = GlobalMaxPool2D()(cnn_output3)
pooling_output4 = GlobalMaxPool2D()(cnn_output4)

pooling_output_merged = concatenate([pooling_output1, pooling_output2, pooling_output3, pooling_output4])

dense1_output = Dense(50, activation="relu")(pooling_output_merged)
dropout1_output = Dropout(0.2)(dense1_output)
output = Dense(6, activation="sigmoid")(dropout1_output)

# Compile Model
model = Model(inputs=input, outputs=output)
print(model.summary())

model.compile(loss='binary_crossentropy', optimizer=Adam(lr=0.0001), metrics=['accuracy', f1_score_metric])

# Callbacks for early stopping and saving the best model
checkpoint = ModelCheckpoint('model-cnn-ensemble.h5', monitor='val_f1_score_metric',
                             verbose=1, save_best_only=True, mode='max')

early_stopping = EarlyStopping(monitor='val_f1_score_metric', patience=5, mode='max')

callbacks_list = [checkpoint, early_stopping]

model.fit(training_input, training_labels, batch_size=1024, epochs=100, callbacks=callbacks_list,
          validation_data=(validation_data[:, 0:max_comment_length], validation_data[:,max_comment_length:156]))


print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-26203590132d> in <cell line: 62>()
#      60
#      61 # Read data
# ---> 62 training_data = np.loadtxt(TRAIN_DATA_FILE, delimiter=',')
#      63 print(training_data.shape)
#      64
#
# /usr/local/lib/python3.10/dist-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1371         delimiter = delimiter.decode('latin1')
#    1372
# -> 1373     arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1374                 converters=converters, skiplines=skiprows, usecols=usecols,
#    1375                 unpack=unpack, ndmin=ndmin, encoding=encoding,
#
# /usr/local/lib/python3.10/dist-packages/numpy/lib/npyio.py in _read(fname, delimiter, comment, quote, imaginary_unit, usecols, skiplines, max_rows, converters, ndmin, unpack, dtype, encoding)
#     990             fname = os.fspath(fname)
#     991         if isinstance(fname, str):
# --> 992             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     993             if encoding is None:
#     994                 encoding = getattr(fh, 'encoding', 'latin1')
#
# /usr/local/lib/python3.10/dist-packages/numpy/lib/_datasource.py in open(path, mode, destpath, encoding, newline)
#     191
#     192     ds = DataSource(destpath)
# --> 193     return ds.open(path, mode, encoding=encoding, newline=newline)
#     194
#     195
#
# /usr/local/lib/python3.10/dist-packages/numpy/lib/_datasource.py in open(self, path, mode, encoding, newline)
#     531                                       encoding=encoding, newline=newline)
#     532         else:
# --> 533             raise FileNotFoundError(f"{path} not found.")
#     534
#     535
#
# FileNotFoundError: /content/drive/My Drive/toxic-comments-classification/toxicity-types-data/training-data-tokenized-augmented.csv not found.

# %% [markdown]
# Ensemble Model

# %%
# !pip install tensorflow==2.0.0 # Install tensorflow version 2.0.0

# %%
# !pip install scikit-learn # Install scikit-learn as it provides the roc_auc_score function

# %%
from keras.layers import Dense, Input, Conv2D, Embedding, Dropout, Reshape, Flatten, concatenate, LSTM, GRU, Bidirectional
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.layers import GlobalMaxPool1D, GlobalMaxPool2D
from keras.optimizers import Adam
from keras.models import Model
from sklearn.metrics import roc_auc_score # Import the roc_auc_score function
import keras.backend as K
import tensorflow as tf
import numpy as np
import random
import time

# fix seeds for re-producability
np.random.seed(7)
tf.random.set_seed(7)
random.seed(7)

def roc_auc_metric(y_true, y_pred):
  return tf.py_function(roc_auc_score, (y_true, y_pred), tf.double) # Remove the extra 'weighted' argument

def get_f1(actual, predicted):
  TP = tf.math.count_nonzero(predicted * actual)
  TN = tf.math.count_nonzero((predicted - 1) * (actual - 1))
  FP = tf.math.count_nonzero(predicted * (actual - 1))
  FN = tf.math.count_nonzero((predicted - 1) * actual)

  precision = tf.divide(TP, TP + FP)
  recall = tf.divide(TP, TP + FN)

  f1 = tf.divide(2 * precision * recall, precision + recall)
  return f1

def f1_score_metric(actual, predicted):
  predicted = tf.cast(predicted>=0.5, tf.int32)
  actual = tf.cast(actual, tf.int32)

  new_overall_f1_weighted = 0

  for class_id in range(0, 6):

    # F1 score
    f1 = get_f1(actual=actual[:, class_id], predicted=predicted[:, class_id])

    new_overall_f1_weighted += f1 * class_percentage[class_id]


  return new_overall_f1_weighted/target

start_time = time.time()

# TRAIN_DATA_FILE = "drive/toxicity type classifier/training-data-tokenized-augemented.csv"
TRAIN_DATA_FILE = "/content/drive/My Drive/toxic-comments-classification/toxicity-types-data/training-data-tokenized.csv"
VALIDATION_DATA_FILE = "/content/drive/My Drive/toxic-comments-classification/toxicity-types-data/validation-data-tokenized.csv"
EMBEDDING_FILE = "/content/drive/My Drive/toxic-comments-classification/toxicity-types-data/fasttext-embedding-matrix.csv"

# TRAIN_DATA_FILE = "training-data-tokenized-augmented-1-2.csv"
# VALIDATION_DATA_FILE = "validation-data-tokenized-augmented-1-2.csv"
# EMBEDDING_FILE = "fasttext-embedding-matrix-augmented-1-2.csv"

# TRAIN_DATA_FILE = "/content/drive/My Drive/toxic-comments-classification/toxicity-types-data/training-data-tokenized.csv"
# VALIDATION_DATA_FILE = "/content/drive/My Drive/toxic-comments-classification/toxicity-types-data/validation-data-tokenized.csv"
# EMBEDDING_FILE = "/content/drive/My Drive/toxic-comments-classification/toxicity-types-data/fasttext-embedding-matrix.csv"


# Parameters
max_comment_length = 150
vector_size = 300

# Read data
training_data = np.loadtxt(TRAIN_DATA_FILE, delimiter=',')
print('shape of training data', training_data.shape)

training_input = training_data[:, 0:max_comment_length]
print(training_input.shape)

training_labels = training_data[:, max_comment_length:156]
print(training_labels.shape)

embedding_matrix = np.loadtxt(EMBEDDING_FILE, delimiter=',')
print(embedding_matrix.shape)
vocab_count = embedding_matrix.shape[0]
print(vocab_count)

validation_data = np.loadtxt(VALIDATION_DATA_FILE, delimiter=',')
validation_labels = validation_data[:, max_comment_length:156]

total_records_count = validation_data.shape[0]
class_records_count = np.sum(validation_labels, axis=0)

print(class_records_count)
print(total_records_count)

class_percentage = (class_records_count/total_records_count)
print(class_percentage)

target = np.sum(class_percentage)
print(target)

# Build model


input = Input(shape=(max_comment_length, ))

x = Embedding(input_dim=vocab_count, output_dim=vector_size, weights=[embedding_matrix], trainable=True)(input)

x_reshaped = Reshape((150, 300, 1))(x)
cnn_output1 = Conv2D(filters=300, kernel_size=(2,300), activation='relu', data_format="channels_last")(x_reshaped)
cnn_output2 = Conv2D(filters=300, kernel_size=(4,300), activation='relu', data_format="channels_last")(x_reshaped)
cnn_output3 = Conv2D(filters=300, kernel_size=(6,300), activation='relu', data_format="channels_last")(x_reshaped)
cnn_output4 = Conv2D(filters=300, kernel_size=(8,300), activation='relu', data_format="channels_last")(x_reshaped)
cnn_pooling_output1 = GlobalMaxPool2D()(cnn_output1)
cnn_pooling_output2 = GlobalMaxPool2D()(cnn_output2)
cnn_pooling_output3 = GlobalMaxPool2D()(cnn_output3)
cnn_pooling_output4 = GlobalMaxPool2D()(cnn_output4)

lstm_output = Bidirectional(LSTM(units=30, activation="tanh", return_sequences=True))(x)
lstm_pooling_output = GlobalMaxPool1D()(lstm_output)

gru_output = Bidirectional(GRU(units=40, activation="tanh", return_sequences=True))(x)
gru_pooling_output = GlobalMaxPool1D()(gru_output)


pooling_output_merged = concatenate([cnn_pooling_output1, cnn_pooling_output2, cnn_pooling_output3, cnn_pooling_output4, lstm_pooling_output, gru_pooling_output])

dense1_output = Dense(200, activation="relu")(pooling_output_merged)
dropout1_output = Dropout(0.2)(dense1_output)

dense2_output = Dense(200, activation="relu")(dropout1_output)
dropout2_output = Dropout(0.2)(dense2_output)

output = Dense(6, activation="sigmoid")(dropout2_output)

# Compile Model
model = Model(inputs=input, outputs=output)
print(model.summary())
print(validation_data.shape)
model.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate=0.0002), metrics=['accuracy', f1_score_metric, roc_auc_metric])

# Callbacks for early stopping and saving the best model
checkpoint = ModelCheckpoint('model-ensemble.h5', monitor='val_get_roc_auc',
                             verbose=1, save_best_only=True, mode='max')

early_stopping = EarlyStopping(monitor='val_get_roc_auc', patience=5, mode='max')

callbacks_list = [checkpoint, early_stopping]

model.fit(training_input, training_labels, batch_size=1024, epochs=100, callbacks=callbacks_list,
          validation_data=(validation_data[:, 0:max_comment_length], validation_data[:,max_comment_length:156]))


print("--- %s seconds ---" % (time.time() - start_time))

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install tensorflow keras
# !pip install scikit-learn
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.17.0)
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (3.4.1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.31.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (71.0.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.64.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.17.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras) (13.7.1)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras) (0.12.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.43.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.7.4)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (2.1.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.3.2)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, roc_auc_score
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv1D, GlobalMaxPooling1D, Embedding, LSTM, GRU, Bidirectional
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import random
import keras.backend as K

random.seed(7)
np.random.seed(7)
tf.random.set_seed(7)

# Load the dataset
train_data = pd.read_csv('/content/drive/My Drive/toxic-comments-classification/toxicity-types-data/training-data-tokenized.csv')  # Adjust the path as needed

# Print the column names to check if 'comment_text' is present and correctly spelled
print(train_data.columns)

# Check if the 'comment' column exists, if so, rename it
if 'comment' in train_data.columns:
    train_data = train_data.rename(columns={'comment': 'comment_text'})
    print("Renamed 'comment' column to 'comment_text'")


# Preprocess the data
max_words = 50000
max_len = 150
tokenizer = Tokenizer(num_words=max_words)
# Use the correct column name here: 'comment_text'
tokenizer.fit_on_texts(train_data['comment_text'])

X = tokenizer.texts_to_sequences(train_data['comment_text'])
X = pad_sequences(X, maxlen=max_len)

y = train_data[['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']].values

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.1, random_state=42)

# Define the model
def build_model():
    model = Sequential()
    model.add(Embedding(max_words, 128, input_length=max_len))
    model.add(Bidirectional(LSTM(64, return_sequences=True)))
    model.add(GlobalMaxPooling1D())
    model.add(Dense(64, activation='relu'))
    model.add(Dense(6, activation='sigmoid'))

    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# Instantiate the model
model = build_model()
model.summary()

# Train the model
history = model.fit(X_train, y_train, epochs=5, batch_size=128, validation_data=(X_val, y_val))

# Save the model
model.save('/content/drive/My Drive/toxic-comments-classification/model-ensemble.h5')

# Evaluate the model
y_pred = model.predict(X_val)
y_pred[y_pred >= 0.5] = 1
y_pred[y_pred < 0.5] = 0

f1 = f1_score(y_val, y_pred, average='macro')
roc_auc = roc_auc_score(y_val, y_pred)

print('Macro F1 Score:', f1)
print('ROC-AUC Score:', roc_auc)
# Out:
# Index(['2.390000000000000000e+02', '1.306100000000000000e+04',
#        '2.390000000000000000e+02.1', '2.286000000000000000e+03',
#        '1.656200000000000000e+04', '2.017000000000000000e+03',
#        '1.125700000000000000e+04', '1.710000000000000000e+02',
#        '2.327000000000000000e+03', '9.870000000000000000e+02',
#        ...
#        '0.000000000000000000e+00.113', '0.000000000000000000e+00.114',
#        '0.000000000000000000e+00.115', '0.000000000000000000e+00.116',
#        '1.000000000000000000e+00', '0.000000000000000000e+00.117',
#        '0.000000000000000000e+00.118', '0.000000000000000000e+00.119',
#        '0.000000000000000000e+00.120', '0.000000000000000000e+00.121'],
#       dtype='object', length=156)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3790         try:
# -> 3791             return self._engine.get_loc(casted_key)
#    3792         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'comment_text'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-02877634625f> in <cell line: 34>()
#      32 tokenizer = Tokenizer(num_words=max_words)
#      33 # Use the correct column name here: 'comment_text'
# ---> 34 tokenizer.fit_on_texts(train_data['comment_text'])
#      35
#      36 X = tokenizer.texts_to_sequences(train_data['comment_text'])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3891             if self.columns.nlevels > 1:
#    3892                 return self._getitem_multilevel(key)
# -> 3893             indexer = self.columns.get_loc(key)
#    3894             if is_integer(indexer):
#    3895                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3796             ):
#    3797                 raise InvalidIndexError(key)
# -> 3798             raise KeyError(key) from err
#    3799         except TypeError:
#    3800             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'comment_text'

# %%
history = model.fit(X_train, y_train, epochs=5, batch_size=128, validation_data=(X_val, y_val))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-302a8d136751> in <cell line: 1>()
# ----> 1 history = model.fit(X_train, y_train, epochs=5, batch_size=128, validation_data=(X_val, y_val))
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/data_adapter_utils.py in <genexpr>(.0)
#     101
#     102 def check_data_cardinality(data):
# --> 103     num_samples = set(int(i.shape[0]) for i in tree.flatten(data))
#     104     if len(num_samples) > 1:
#     105         msg = (
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %% [markdown]
# Evaluate Single Model

# %%
from sklearn.metrics import auc, roc_curve, confusion_matrix, f1_score
from sklearn.metrics import roc_auc_score
from keras.models import load_model
from keras.layers import Lambda
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import random
import keras.backend as K

# fix seeds for re-producability
random.seed(7)
np.random.seed(7)
tf.random.set_seed(7)

def get_f1(actual, predicted):
  TP = tf.count_nonzero(predicted * actual)
  TN = tf.count_nonzero((predicted - 1) * (actual - 1))
  FP = tf.count_nonzero(predicted * (actual - 1))
  FN = tf.count_nonzero((predicted - 1) * actual)

  precision = tf.divide(TP, TP + FP)
  recall = tf.divide(TP, TP + FN)

  f1 = tf.divide(2 * precision * recall, precision + recall)

  return f1

# def f1_score_metric(actual, predicted):
#   predicted = tf.to_int32(predicted>=0.5)
#   actual = tf.to_int32(actual)

#   new_overall_f1_weighted = 0

#   for class_id in range(0, 6):

#     # F1 score
#     f1 = get_f1(actual=actual[:, class_id], predicted=predicted[:, class_id])

#     new_overall_f1_weighted += f1 * class_percentage[class_id]

#   return new_overall_f1_weighted/target

def f1_score_metric(y_true, y_pred):
    y_pred = tf.cast(y_pred>=0.5, tf.int32)
    y_true = tf.cast(y_true, tf.int32)

    tp = K.sum(K.cast(y_true*y_pred, 'float'), axis=0)
    tn = K.sum(K.cast((1-y_true)*(1-y_pred), 'float'), axis=0)
    fp = K.sum(K.cast((1-y_true)*y_pred, 'float'), axis=0)
    fn = K.sum(K.cast(y_true*(1-y_pred), 'float'), axis=0)

    p = tp / (tp + fp + K.epsilon())
    r = tp / (tp + fn + K.epsilon())

    f1 = 2*p*r / (p+r+K.epsilon())
    f1 = tf.where(tf.math.is_nan(f1), tf.zeros_like(f1), f1)
    return K.mean(f1)

def flip(x):
  import keras.backend as k
  return k.reverse(x,axes=0)

VALIDATION_DATA_FILE = "drive/My Drive/Deep Learning in NLP/toxicity type classifier/validation-data-tokenized.csv"

max_comment_length = 150

# Read data
validation_data = np.loadtxt(VALIDATION_DATA_FILE, delimiter=',')
print(validation_data.shape)

validation_input = validation_data[:, 0:max_comment_length]
print(validation_input.shape)

validation_labels = validation_data[:, max_comment_length:156]
print(validation_labels.shape)

total_records_count = validation_labels.shape[0]

class_records_count = np.sum(validation_labels, axis=0)

print(class_records_count)
print(total_records_count)
class_percentage = (class_records_count/total_records_count)
print(class_percentage)
target = np.sum(class_percentage)
print(target)

layer = Lambda(flip)

# load model
model = load_model('/content/drive/My Drive/Deep Learning in NLP/toxicity type**/model-ensemble.h5', custom_objects={'f1_score_metric': f1_score_metric, 'layer': layer})
# model = load_model('model-ensemble.h5', custom_objects={'f1_score_metric': f1_score_metric, 'layer': layer})
# model = load_model('drive/My Drive/Deep Learning in NLP/toxicity type**/model-cnn-ensemble.h5', custom_objects={'f1_score_metric': f1_score_metric, 'layer': layer})

y_pred = model.predict(validation_input)



y_pred[y_pred >= 0.5] = 1
y_pred[y_pred < 0.5] = 0

xx = f1_score(y_true=validation_labels, y_pred=y_pred, average=None)
print(xx)
print('macro', sum(xx)/6)

# Compute ROC
roc_auc = roc_auc_score(y_true=validation_labels, y_score=y_pred)
print('new roc-auc', roc_auc)

# Confusion matrix and F1 scores
print('**************************************\n')
new_overall_f1_weighted = 0

for class_id in range(0, 6):
  print('Class ', class_id)

  # F1 score
  f1_not_weighted = f1_score(y_true=validation_labels[:, class_id], y_pred=y_pred[:, class_id], average=None, pos_label=1)
  print('F1 Score =', f1_not_weighted)

  print('F1 score for positive class, weighted by the class percentage = ', f1_not_weighted[1]*class_percentage[class_id])
  new_overall_f1_weighted += f1_not_weighted[1]*class_percentage[class_id]

  f1_weighted = f1_score(y_true=validation_labels[:, class_id], y_pred=y_pred[:, class_id], average='macro', pos_label=1)
  print('Weighted F1 Score =', f1_weighted)

  roc_auc = roc_auc_score(validation_labels[:, class_id], y_score=y_pred[:, class_id])
  print('class roc-auc', roc_auc)

  print('**************************************\n')


f1_all_classes = f1_score(y_true=validation_labels, y_pred=y_pred, average='macro')
print('macro average F1 score over all classes =', f1_all_classes)
f1_all_classes = f1_score(y_true=validation_labels, y_pred=y_pred, average='micro')
print('micro average F1 score over all classes =', f1_all_classes)

print('new_overall_f1_weighted = ', new_overall_f1_weighted)
print('to go= ', target-new_overall_f1_weighted)
print('to go ratio = ',  new_overall_f1_weighted/target)

new_f1 = 0
for i in range(0, total_records_count):
  actual = validation_labels[i]
  predicted = y_pred[i]

  correct = 0
  for j in range(0, 6):
    if actual[j] == predicted[j]:
      correct += 1

  new_f1 += 2*correct / 12

print('new f1 = ', new_f1/total_records_count)

# %% [markdown]
# Evaluate Ensemble Model

# %%
from sklearn.metrics import roc_auc_score
from keras.models import load_model
import matplotlib.pyplot as plt
from sklearn.metrics import auc, roc_curve, confusion_matrix, f1_score
import tensorflow as tf
import numpy as np
import random

# fix seeds for re-producability
random.seed(7)
np.random.seed(7)
tf.set_random_seed(7)

def f1_score_metric(actual, predicted):
  predicted = tf.to_int32(predicted>=0.5)
  actual = tf.to_int32(actual)

  TP = tf.count_nonzero(predicted * actual)
  TN = tf.count_nonzero((predicted - 1) * (actual - 1))
  FP = tf.count_nonzero(predicted * (actual - 1))
  FN = tf.count_nonzero((predicted - 1) * actual)

  precision = tf.divide(TP, TP + FP)
  recall = tf.divide(TP, TP + FN)

  f1 = tf.divide(2 * precision * recall, precision + recall)


  return f1

VALIDATION_DATA_FILE = "drive/toxicity type classifier/validation-data-tokenized.csv"

# Read data
validation_data = np.loadtxt(VALIDATION_DATA_FILE, delimiter=',')
print(validation_data.shape)

validation_input = validation_data[:, 0:150]
print(validation_input.shape)

validation_labels = validation_data[:, 150:156]
print(validation_labels.shape)

# load models
cnn_model = load_model('drive/Deep Learning in NLP /toxicity type**/model-cnn-ensemble.h5', custom_objects={'f1_score_metric': f1_score_metric})
lstm_model = load_model('drive/Deep Learning in NLP /toxicity type**/model-lstm.h5', custom_objects={'f1_score_metric': f1_score_metric})
gru_model = load_model('drive/Deep Learning in NLP /toxicity type**/model-gru.h5', custom_objects={'f1_score_metric': f1_score_metric})

print('models loaded')

cnn_y_pred = cnn_model.predict(validation_input)
print(cnn_y_pred[5])

lstm_y_pred = lstm_model.predict(validation_input)
print(lstm_y_pred[5])

gru_y_pred = gru_model.predict(validation_input)
print(gru_y_pred[0])


sum_prediction1 = cnn_y_pred + lstm_y_pred + gru_y_pred
print(sum_prediction1[5])
# sum_prediction1 /= 3
print(sum_prediction1[5])
# Compute ROC
roc_auc = roc_auc_score(y_true=validation_labels, y_score=sum_prediction1, average='weighted', sample_weight=None)
print('roc-auc', roc_auc)

roc_auc = roc_auc_score(y_true=validation_labels, y_score=sum_prediction)
print('new roc-auc', roc_auc)

cnn_y_pred[cnn_y_pred >= 0.5] = 1
cnn_y_pred[cnn_y_pred < 0.5] = 0

lstm_y_pred[lstm_y_pred >= 0.5] = 1
lstm_y_pred[lstm_y_pred < 0.5] = 0

gru_y_pred[gru_y_pred >= 0.5] = 1
gru_y_pred[gru_y_pred < 0.5] = 0

print(cnn_y_pred[5])
print(lstm_y_pred[5])
print(gru_y_pred[5])


cnn_y_pred = np.array(cnn_y_pred)
lstm_y_pred = np.array(lstm_y_pred)
gru_y_pred = np.array(gru_y_pred)

sum_prediction = cnn_y_pred + lstm_y_pred + gru_y_pred
print(sum_prediction.shape)
print(sum_prediction[5])

sum_prediction[sum_prediction < 2] = 0
sum_prediction[sum_prediction >= 2] = 1
print(sum_prediction[5])

# Confusion matrix and F1 scores
print('**************************************\n')
y_pred = sum_prediction
print(y_pred.shape)
new_overall_f1_weighted = 0

for class_id in range(0, 6):
  print('Class ', class_id)
  print(validation_labels[:, class_id])

  # F1 score
  f1_not_weighted = f1_score(y_true=validation_labels[:, class_id], y_pred=y_pred[:, class_id], average=None, pos_label=1)
  print('F1 Score =', f1_not_weighted)

  print('F1 score for positive class, weighted by the class percentage = ', f1_not_weighted[1]*class_percentage[class_id])
  new_overall_f1_weighted += f1_not_weighted[1]*class_percentage[class_id]

  f1_weighted = f1_score(y_true=validation_labels[:, class_id], y_pred=y_pred[:, class_id], average='weighted', pos_label=1)
  print('Weighted F1 Score =', f1_weighted)

  print('**************************************\n')


f1_all_classes = f1_score(y_true=validation_labels, y_pred=y_pred, average='micro')
print('micro F1 score over all classes =', f1_all_classes)

print('new_overall_f1_weighted = ', new_overall_f1_weighted)
print('to go= ', target-new_overall_f1_weighted)
print('to go ratio = ',  new_overall_f1_weighted/target)

new_f1 = 0
for i in range(0, total_records_count):
  actual = validation_labels[i]
  predicted = y_pred[i]

  correct = 0
  for j in range(0, 6):
    if actual[j] == predicted[j]:
      correct += 1

  new_f1 += 2*correct / 12

print('new f1 = ', new_f1/total_records_count)
